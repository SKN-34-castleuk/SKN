# %% [markdown]
# # 09 예외처리

# %%
try : 
    4/0
except:
    print("예외 발생")
# Out:
# 예외 발생

# %%
try:
    a = [1,2,3]
    print(a[3])
    4/0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다. ")
except IndexError:
    print("인덱싱 할 수 없습니다. ")
except:     # except는 마지막에만 들어올수있다
    print("아무튼 에러")
# Out:
# 인덱싱 할 수 없습니다.

# %%
try:
    4/0
except ZeroDivisionError as e:
    print(e,"오류발생")
# Out:
# division by zero 오류발생

# %%
f = None

try:
    f = open('foo.txt', 'r')
    # 동작할 코드 내용 작성

finally:
    if f:
        print("파일 닫기")
        f.close()   # try 블럭 수행 중간에 오류가 발생하더라도 마지막에 무조건 실행된다.
        print("\n정상 실행 완료")
# Out:
# 파일 닫기
#
# 정상 실행 완료

# %%
try:
    age = int(input("나이를 입력하세요 : "))
except:
    print("입력값이 정확하지 않습니다.")
else:
    if age <= 18:
        print("미성년자는 출입금지입니다.")
    else:
        print("환영합니다.")
# Out:
# 환영합니다.

# %%
try:
    a = [1,2,3]
    print(a[3])
    4/0
except (ZeroDivisionError,IndexError) as e:
    print(e)
except:     # except는 마지막에만 들어올수있다
    print("아무튼 에러")
# Out:
# list index out of range
