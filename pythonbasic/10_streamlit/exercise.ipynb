# %% [markdown]
# local URL : http://localhost:8501
# localhost =
# 8501은 포트번호
#
# Network URL: http://192.168.0.30:8501
# 192.168.0.30

# %% [markdown]
# | **입력 타입** | **동작 설명** |
# | --- | --- |
# | **문자열 (string)** | Markdown으로 렌더링됨. LaTeX, 이모지, 색상 표현도 지원 |
# | **데이터프레임 (data_frame)** | 데이터프레임을 대화형 표로 출력 |
# | **숫자 (int, float)** | 숫자를 화면에 출력 |
# | **딕셔너리 (dict)** | 딕셔너리를 대화형 뷰어로 출력 |
# | **리스트 (list)** | 리스트를 대화형 뷰어로 출력 |
# | **함수 (function)** | 함수에 대한 정보를 출력 |
# | **모듈 (module)** | 모듈에 대한 정보를 출력 |
# | **그래프 (matplotlib, Altair, etc.)** | 그래프를 화면에 출력 |
# | **예외 (Exception)** | 예외 메시지를 화면에 출력 |
# | **HTML (_repr_html_())** | 객체의 HTML 표현을 사용하여 화면 출력 (unsafe_allow_html 설정 시) |

# %% [markdown]
# # 123
# ## 123
# ### 123
