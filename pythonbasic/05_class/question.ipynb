# %% [markdown]
# # 7 클래스와 인스턴스

# %% [markdown]
# ### **문제 1: 클래스 속성, 인스턴스 속성 테스트**
#
# 카피바라는 이직 준비를 위해 자기소개서를 작성해야 합니다. `Squirrel`이라는 클래스를 만들어 카피바라의 기본 정보를 설정하세요.
#
# 1. 클래스 속성 `species`를 설정하여 "카피바라"로 초기화하세요.
# 2. 생성자를 통해 인스턴스 속성 `name`과 `current_job`을 설정하세요.
# 3. 메서드 `introduce`를 만들어 이름과 현재 직업을 소개하는 문자열을 반환하세요.
# 4. 다른 인스턴스를 생성해도 `species`는 공유되지만, `name`과 `current_job`은 서로 독립적임을 확인하세요.

# %%
class Squirrel():
    species = '카피바라'
    def __init__(self,name,current_job):
        self.name = name
        self.current_job = current_job
    def introduce(self):
        return f"안녕하세요 저는 {self.name}입니다. 현재직업은 {self.current_job}입니다."

p1 = Squirrel('카피','강사')
p2 = Squirrel('바라','빵')

print(p1.species)
print(p2.species)
print(p1.introduce())
print(p2.introduce())
print(p1.species)
# Out:
# 카피바라
# 카피바라
# 안녕하세요 저는 카피입니다. 현재직업은 강사입니다.
# 안녕하세요 저는 바라입니다. 현재직업은 빵입니다.
# 카피바라

# %% [markdown]
# ### **문제 2: 클래스 속성과 인스턴스 속성의 차이**
#
# 카피바라는 이직 준비를 하며 다양한 직업 스킬을 학습 중입니다. 클래스 속성과 인스턴스 속성의 차이를 확인하세요.
#
# 1. `Character` 클래스를 생성하세요.
# 2. 클래스 속성 `skills`를 정의하여 빈 리스트로 초기화하세요.
# 3. 생성자에서 인스턴스 속성 `skills`를 별도로 초기화하세요.
# 4. `add_skill` 메서드에서 클래스 속성이 아닌 인스턴스 속성에 스킬을 추가하도록 수정하세요.

# %%
class Character:    
    skills = []  
    def __init__(self):
        self.skills = []
    def add_skill(self, skills):
        self.skills.append(skills)
    def show_skill(self):
        return f"{self.skills}를 가지고있다"
my_character = Character()
your_character = Character()

my_character.add_skill(['불날리기'])
my_character.add_skill(['날라차기'])
my_character.add_skill(['돌려차기'])
my_character.add_skill(['머리치기'])
your_character.add_skill('다떄리기')

print(my_character.show_skill())
print(your_character.show_skill())
# Out:
# [['불날리기'], ['날라차기'], ['돌려차기'], ['머리치기']]를 가지고있다
# ['다떄리기']를 가지고있다

# %%
class Character:    
    skills = []  
    def add_skill(self, skills):
        self.skills.append(skills)
    def show_skill(self):
        return f"{self.skills}를 가지고있다"
my_character = Character()
your_character = Character()

my_character.add_skill('불날리기')
your_character.add_skill('다떄리기')

print(my_character.show_skill())
print(your_character.show_skill())
# Out:
# ['불날리기', '다떄리기']를 가지고있다
# ['불날리기', '다떄리기']를 가지고있다

# %% [markdown]
# ### **문제 3: 인스턴스 속성과 클래스 속성의 우선순위**
#
# 카피바라는 이직을 위해 별명을 여러 개 사용합니다. 클래스 속성으로 `nickname`을 설정하지만, 각 인스턴스마다 별명을 변경할 수 있습니다.
#
# 1. `Character` 클래스에 클래스 속성 `nickname`을 설정하세요.
# 2. 생성자에서 인스턴스 속성 `nickname`을 설정하세요.
# 3. 클래스 속성과 인스턴스 속성이 충돌할 때, 인스턴스 속성이 우선됨을 확인하세요.

# %%
class Character:
    nickname = 'poor'    
    def __init__(self, nickname):
        self.nickname = nickname
        self.type = type


my_character = Character('카피바라')
my_character2 = Character('호랑이')

print(my_character.nickname)
print(my_character2.nickname)
# Out:
# 카피바라
# 호랑이

# %% [markdown]
# ### **문제 4: 네임스페이스 테스트 - 전역과 로컬**
#
# 카피바라는 이직 준비 도구를 사용하며, 전역 변수와 로컬 변수를 관리합니다. `namespace_test` 함수를 작성해 네임스페이스를 테스트하세요.
#
# 1. 전역 변수 `tool`을 "연필"로 설정하세요.
# 2.  함수 `namespace_test` 내부에 로컬 변수 `local_tool`을 "키보드"로 설정하고, `global` 키워드를 사용해 전역 변수를 "펜"으로 수정하세요.
# 3. 함수 내부에서 로컬 변수와 전역 변수의 값을 출력하세요.

# %%
tool = "연필"
def namespace_test():
    local_tool = '키보드'
    global tool
    tool = '펜'
    # print(tool)
    print(local_tool)

namespace_test()
print(tool)
# Out:
# 키보드
# 펜

# %% [markdown]
# ### **문제 5: 네임스페이스 테스트 - 클래스와 인스턴스**
#
# 카피바라는 이직 준비 중 클래스를 통해 도구를 관리합니다. `Toolbox` 클래스를 만들어 네임스페이스를 테스트하세요.
#
# 1. 클래스 속성 `tools`를 ["노트북", "책상"]으로 초기화하세요.
# 2. 생성자를 통해 인스턴스 속성 `tools`를 설정하고, 객체마다 다른 도구를 가질 수 있도록 설정하세요.
# 3. `add_tool` 메서드를 만들어 인스턴스 속성에 새 도구를 추가하세요.

# %%
class Toolbox:
    tools = ['노트북','책상']
    def __init__(self):
        self.tools = []
        
    def add_tool(self,tools):
        self.tools.append(tools)
        
    

a = Toolbox()
b = Toolbox()
a.add_tool("연필")
print(a.tools)
b.add_tool("펜")
b.add_tool("펜")
b.add_tool("펜")
b.add_tool("펜")
b.add_tool("펜")
print(b.tools)
a.add_tool("qk")
a.add_tool("핀z")
a.add_tool("핀d")
a.add_tool("핀f")
print(a.tools)
print(b.tools)
print(b.tools)

print(Toolbox.tools)
# Out:
# ['연필']
# ['펜', '펜', '펜', '펜', '펜']
# ['연필', 'qk', '핀z', '핀d', '핀f']
# ['펜', '펜', '펜', '펜', '펜']
# ['펜', '펜', '펜', '펜', '펜']
# ['노트북', '책상']

# %% [markdown]
# ### **문제 6: 네임스페이스 테스트 - nonlocal**
#
# 카피바라는 이직 준비 중 추가적인 정보가 필요합니다. 중첩 함수와 `nonlocal` 키워드를 사용해 바깥 함수의 변수를 수정하세요.
#
# 1. 함수 `nested_function`을 작성하세요.
#
# 1. 바깥 함수의 변수 `status`를 "작성 중"으로 초기화하세요.
# 2. 중첩 함수에서 `status`를 "완료"로 수정하세요.

# %%
def nested_funtion():
    status = "작성 중"
    

    def nested_funtion_2():
        nonlocal status
        status = "완료"
    print(status)   # 작성중
    nested_funtion_2()
    print(status)  # 완료

    

nested_funtion()
# Out:
# 작성 중
# 완료

# %% [markdown]
# # 8 상속

# %% [markdown]
# ### 문제 1: 기본 상속을 활용한 클래스 생성
#
# 카피바라는 이직을 준비하며 새로운 직업군을 탐색하고 있습니다. 카피바라의 기본적인 정보를 담는 `Person` 클래스를 만들고, 이를 상속받는 `Candidate` 클래스를 생성하세요.
#
# 1. `Person` 클래스:
#     - 클래스 속성 `national`은 "Korea"로 설정합니다.
#     - 메서드 `introduce`는 `"안녕하세요, 저는 한국에서 왔습니다."`를 반환합니다.
# 2. `Candidate` 클래스:
#     - `Person` 클래스를 상속받습니다.
#     - 생성자에서 이름(`name`)과 관심 분야(`field`)를 매개변수로 받아 저장합니다.
#     - 메서드 `introduce`를 오버라이드하여 `"안녕하세요, 저는 [name]입니다. [field] 분야에 관심이 있습니다."`를 반환합니다.

# %%
class Person:
    national = "Korea"
    def introduce(self):
        return "안녕하세요, 저는 한국에서 왔습니다."
    
class Candidate(Person):
    def __init__(self,name,field):
        self.name = name
        self.field = field
    def introduce(self):
        return f"안녕하세요, 저는 {self.name}입니다. {self.field} 분야에 관심이 있습니다."

per = Person()
candidate = Candidate("a","Python")

print(candidate.introduce())
print(candidate.name)
print(candidate.national)
print(per.national)
print(per.introduce())
# Out:
# 안녕하세요, 저는 a입니다. Python 분야에 관심이 있습니다.
# a
# Korea
# Korea
# 안녕하세요, 저는 한국에서 왔습니다.

# %% [markdown]
# ### 문제 2: **다중 상속을 활용한 클래스 생성**
#
# 카피바라는 이직을 준비하며 여러 강사님들의 도움을 받고 있습니다. 강사의 역할을 분리한 클래스를 만들어 상속 구조를 테스트하세요.
#
# 1. `Mentor` 클래스:
#     - 메서드 `guide`는 `"이직 준비를 도와드립니다."`를 반환합니다.
# 2. `Lecturer` 클래스:
#     - 메서드 `teach`는 `"이직에 필요한 기술을 가르쳐드립니다."`를 반환합니다.
# 3. `Coach` 클래스:
#     - `Mentor`와 `Lecturer` 클래스를 다중 상속받습니다.
#     - 메서드 `support`는 `"여러 방면으로 지원을 아끼지 않겠습니다."`를 반환합니다.

# %%
class Mentor:
    def guide(self):
        return "이직 준비를 도와드립니다."
    
class Lecturer:
    def teach(self):
        return "이직에 필요한 기술을 가르쳐드립니다."
    
class Coach(Mentor,Lecturer):
    def support(self):
        return "여러방변으로 지원을 아끼지 않겠습니다."
    

coach = Coach()
print(coach.guide())
print(coach.teach())
print(coach.support())
# Out:
# 이직 준비를 도와드립니다.
# 이직에 필요한 기술을 가르쳐드립니다.
# 여러방변으로 지원을 아끼지 않겠습니다.

# %% [markdown]
# ### 문제 3: **부모 클래스 메서드 오버라이딩**
#
# 카피바라는 이직 준비를 위해 개인적인 특성을 강조하고 있습니다. 부모 클래스의 메서드를 오버라이딩하여 각기 다른 인스턴스를 만들어보세요.
#
# 1. `Person` 클래스:
#     - 속성 `name`과 `national`을 생성자로 받아 저장합니다.
#     - 메서드 `introduce`는 `"안녕하세요, 저는 [name]입니다. 저는 [national]에서 왔습니다."`를 반환합니다.
# 2. `Candidate` 클래스:
#     - `Person` 클래스를 상속받습니다.
#     - `introduce` 메서드를 오버라이드하여 `"안녕하세요, 제 이름은 [name]이고, 이직 준비 중입니다."`를 반환합니다.

# %%
class Person:
    def __init__(self,name,national):
        self.name = name
        self.national = national
    def introduce(self):
        return f"안녕하세요, 저는 {self.name}입니다. 저는 {self.national}에서 왔습니다."
    
class Candidate(Person):
    # def __init__(self,name,national):
    #     self.name = name           # 안써도 됌
    #     self.national = national
    def introduce(self):
        return f"안녕하세요, 저 이름은 {self.name}이고, 이직 준비 중입니다."


candidate = Candidate("성욱","한국")
print(candidate.introduce())
candidate2 = Candidate("바보","한국")
print(candidate2.introduce())
# Out:
# 안녕하세요, 저 이름은 성욱이고, 이직 준비 중입니다.
# 안녕하세요, 저 이름은 바보이고, 이직 준비 중입니다.

# %% [markdown]
# ### 문제 4: **상속의 특성 통합 테스트**
#
# 카피바라는 강사님들의 지도를 받으며 다양한 분야에서 경험을 쌓고 있습니다. 상속과 메서드 오버라이딩, 다중 상속을 종합적으로 테스트하세요.
#
# 1. `Mentor` 클래스:
#     - 속성 `field`를 생성자로 받아 저장합니다.
#     - 메서드 `guide`는 `"저는 [field] 분야의 멘토입니다."`를 반환합니다.
# 2. `Lecturer` 클래스:
#     - 속성 `experience`를 생성자로 받아 저장합니다.
#     - 메서드 `teach`는 `"저는 [experience]년의 강의 경력을 가지고 있습니다."`를 반환합니다.
# 3. `Candidate` 클래스:
#     - `Mentor`와 `Lecturer` 클래스를 다중 상속받습니다.
#     - `guide` 메서드를 오버라이드하여 `"저는 [field] 분야의 강사이며, 이직 준비를 도와드립니다."`를 반환합니다.

# %%
class Mentor:
    def __init__(self,field):
        self.field = field
    def guide(self):
        return f"저는 {self.field} 분야의 멘토입니다."
    
class Lecturer:
    def __init__(self,experience):
        self.experience = experience
    def teach(self):
        return f"저는 {self.experience}년의 강의 경력을 가지고 있습니다."
    
class Candidate(Mentor,Lecturer):
    def __init__(self, field, experience):
        Mentor.__init__(self, field)
        Lecturer.__init__(self, experience)
    def guide(self):
        return f"저는 {self.field} 분야의 강사이며, 이직준비를 도와드립니다."


mentor = Mentor("파이썬")
lect = Lecturer(25)
cand = Candidate('자바', 10)

print(mentor.guide())
print(lect.teach())

print(cand.teach())
print(cand.guide())
# Out:
# 저는 파이썬 분야의 멘토입니다.
# 저는 25년의 강의 경력을 가지고 있습니다.
# 저는 10년의 강의 경력을 가지고 있습니다.
# 저는 자바 분야의 강사이며, 이직준비를 도와드립니다.
