# %%
f = open("C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt",'w',encoding = 'utf-8')

# %%
f.write('바보 개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n')
f.close()

# %%
f = open("C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt",'w',encoding = 'utf-8')

# %%
data = ['rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바\n\n',
        '네가 울면 무지개 연못에 비가 온단다\n', 
        '비바람 몰아쳐도 이겨내고\n', 
        '일곱번 넘어져도 일어나~라\n', 
        '울지말고 일어나 피리를 불어라\n\n', 
        '삘릴리 개굴개굴 삘릴리리\n', 
        '삘릴리 개굴개굴 삘릴리리\n\n',
        '무지개 연못에 웃음꽃 핀다.\n'
        ]

f.writelines(data)

# %%
f = open("C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt",'r',encoding = 'utf-8')

data = f.read()
print(data)

f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open("flog_song.txt",'r',encoding = 'utf-8')

data = f.read()
print(data)

f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open("C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt",'r',encoding = 'utf-8')

line = f.readline()
print(line)

f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open("./flog_song.txt",'r',encoding = 'utf-8')

line = f.readline()
print(line)

f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open('C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt', 'r', encoding='utf-8')

line = f.readlines()
# print("\n".join(line))
print(line)
f.close()
# Out:
# ['rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바\n', '\n', '네가 울면 무지개 연못에 비가 온단다\n', '비바람 몰아쳐도 이겨내고\n', '일곱번 넘어져도 일어나~라\n', '울지말고 일어나 피리를 불어라\n', '\n', '삘릴리 개굴개굴 삘릴리리\n', '삘릴리 개굴개굴 삘릴리리\n', '\n', '무지개 연못에 웃음꽃 핀다.\n']

# %%
f = open('C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt', 'r', encoding='utf-8')


while True:
  line = f.readline()
  
  if not line:
    break
  print(line)
  
f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt', 'r', encoding='utf-8')

lines = f.readlines()
# print(lines)
for line in lines:
    print(line)
f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open("./flog_song.txt", 'r', encoding='utf-8')

for line in f:
    print(line)

f.close()
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f1 = open("./flog_song.txt", 'a', encoding='utf-8')
f1.write("노래 끝")
f1.close()

f2 = open("C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt", 'r', encoding='utf-8')
data = f2.read()
print(data)
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래 끝

# %%
f1 = open("./flog_song.txt", 'a', encoding='utf-8')
f1.write(str(51515151))
f1.write("\n")
f1.write("15151515\n")
f1.close()

f2 = open("C:/Users/uk/SKN/pythonbasic/08_file-io/flog_song.txt", 'r', encoding='utf-8')
data = f2.read()
print(data)
# Out:
# rabbit 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래 끝
# 51515151
# 15151515

# %%
with open("newfile.txt", "w",encoding="utf-8") as f:
    f.write("Life is too short, you need python")

# %%
with open("newfile.txt", "a",encoding="utf-8") as f:
    f.write("\n poor boy")

# %%
with open("newfile.txt", "r",encoding="utf-8") as f:
    data = f.read()
    print(data)
# Out:
# Life is too short, you need python
#  poor boy

# %%
import os
os.makedirs("test",exist_ok=True)
