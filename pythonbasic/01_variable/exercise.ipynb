# %% [markdown]
# 변수 생성
#
# 변수명 = 자료

# %%
name = "capybara"
age = 100

print(name)
print(age)
print(age)
print(age)
# Out:
# capybara
# 100
# 100
# 100

# %%
score = 10
print(score)
score = 20
print(score)
# Out:
# 10
# 20

# %%
# int num =1
# num = '1'
# Out:
# 20

# %%
x = 10
y = x+5

print(x,y) # 15
# Out:
# 10 15

# %%
team_name = "ohgirafffers"

my_team = team_name

print(my_team)
# Out:
# ohgirafffers

# %%
# print(age2)
# name = 홍길동
# print(Name)

# %%
heightrt = 207.3
a  = 171.8

# %%
#스네이크 케이스
team_name = "오지라퍼스"
print(team_name)

Team_name = "Ohgirafffers"
print(team_name)
print(Team_name)
# Out:
# 오지라퍼스
# 오지라퍼스
# Ohgirafffers

# %%
우리팀 =  "오지라퍼스" 
#한글 변수명 가능하지만 사용 지양,가독성 X

# %%
team_1_name = "오지라퍼스"

# 1_team_name = "오지라퍼스"    # 컴파일 오류 발생
# 20240101 = "오지라퍼스"       # 컴파일 오류 발생

print(team_1_name)
# print(1_team_name)
# print(20240101)

# %%
team_@_name = "오지라퍼스"    # SyntaxError 발생

else = "오지라퍼스"    # 컴파일 오류 발생
# Out:
#   Cell In[15], line 1
#     team_@_name = "오지라퍼스"    # SyntaxError 발생
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
10
# Out:
# 10

# %%
print(_)
print(_ * 3)
# Out:
# 10
# 30

# %%
# 특정 값을 무시
x,_,z =(1,2,3)
print(x) # 1
print(z) # 3
# 앞에 *을 추가로 붙여 여러 개의 값 무시
x,*_,y = (1,2,3,4,5)
print(x) # 1
print(y) # 5
# Out:
# 1
# 3
# 1
# 5

# %%
for _ in range(3):
    print("hello")
# Out:
# hello
# hello
# hello

# %%
_internal_name = 'one_module' # private 변수
_internal_version = '1.0'     # private 변수
# Out:
# one_module

# %%
million = 1_000_000
print(million)
# Out:
# 1000000

# %%
for_ = 'for blah'
print(for_)
# Out:
# for blah

# %% [markdown]
# _ -> 내부용  또느 값 무시
# __ -> private 용도(외부접근 차단)
#   __name__ -> 파이썬에서 정의한 특수 메서드(매직 메서드)
