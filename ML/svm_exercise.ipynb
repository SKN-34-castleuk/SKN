# %%
from sklearn.svm import SVC
from sklearn.datasets import make_blobs   # 군집 클래스를 가지는 데이터셋
import matplotlib.pyplot as plt

# 데이터 생성
X, y = make_blobs(n_samples=100, centers=2, random_state=6)

# 선형 SVM 모델 학습
model = SVC(kernel='linear')
model.fit(X, y)

# 시각화
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter')
plt.title("Linear SVM Decision Boundary")
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# 데이터 생성
X, y = make_circles(n_samples=100,  
                     factor=0.5,    # 반지름 크기 0.5
                     noise=0.1      # 이상치 데이터는 10%정도는 씀
                     )

# 비선형 SVM 모델 학습 (RBF 커널)
model = SVC(
    kernel='rbf',   # 가우시안 커널(비선형)
    gamma=1         # 결정 경계의 굴곡
    )
model.fit(X, y)

# 시각화
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter')
plt.title("Nonlinear SVM Decision Boundary")
plt.show()

# %%
from sklearn.svm import SVR
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
X = np.linspace(0, 10, 100).reshape(-1, 1)      # 0에서 10까지 데이터 100가지를 2차원형태로 재가공 
y = np.sin(X).ravel() + np.random.normal(0, 0.1, X.shape[0])    # 사인함수 + 노이즈 추가

# SVM 회귀 모델 학습
model = SVR(
    kernel='rbf',   # 비선형
    C=1,            # 오차에 대한 패널티 강도 (오차를 얼마나 허용할지 : 경계의 모양)
                    # c값을 크게주면(100~1000) 경계가 구불구불(과적합 가능성), 
                    # 작게 주면(0.1~0.001) 경계가 부드러움 (과소적합 가능성)
    epsilon=0.1     # 오차 허용 구간 (오차라고 보지않을 허용 범위 폭)(0.1이 일반적인 형태)
)
model.fit(X, y)

# 예측 및 시각화
y_pred = model.predict(X)
plt.scatter(X, y, label="Data")
plt.plot(X, y_pred, color='red', label="SVR Fit")
plt.legend()
plt.show()
