# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
s = pd.Series([10,20,30,40], index = ['a','b','c','d'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
print(s['b'])
# Out:
# 20

# %%
s = pd.Series([10,20,30,40], index = ['2026-07-01','2026-07-02','2026-07-03','2026-07-04'])
print(s)
# Out:
# 2026-07-01    10
# 2026-07-02    20
# 2026-07-03    30
# 2026-07-04    40
# dtype: int64

# %%
print(s['2026-07-01'])
# Out:
# 10

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df[['Name']]
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David

# %%
row = []
for i in range(4):
    row.append(data['Name'][i])
for ch in row:
    print(*ch)
# Out:
# A l i c e
# B o b
# C h a r l i e
# D a v i d

# %%
print(df.loc[2]) #인덱스 2
print(df.iloc[2]) #순서상 n번째
# Out:
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)

print(df['City']) # Sefies
print(df[['City']])  #DataFrame
# Out:
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# Name: City, dtype: str
#           City
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston

# %%
print(df.loc[1])   # 인덱스가 1인 데이터
print()
print(df.iloc[2])  # 순서상 위에서 3번째행
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object
#
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
a= df['Age'] >= 30
df[a]
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df[df["Age"]>=30]
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df['Country'] = ['USA','USA','USA','USA']
df
# Out:
#       Name  Age         City Country
# 0    Alice   25     New York     USA
# 1      Bob   30  Los Angeles     USA
# 2  Charlie   35      Chicago     USA
# 3    David   40      Houston     USA

# %%
df.loc[4] = ['Eve',28,'San Francisco','USA']
df
# Out:
#       Name  Age           City Country
# 0    Alice   25       New York     USA
# 1      Bob   30    Los Angeles     USA
# 2  Charlie   35        Chicago     USA
# 3    David   40        Houston     USA
# 4      Eve   28  San Francisco     USA

# %%
df = df.drop('Country',axis = 1)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   40        Houston
# 4      Eve   28  San Francisco

# %%
# df = df.drop(0)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   40        Houston
# 4      Eve   28  San Francisco

# %%
df.drop(4,inplace=True)  # inplace는 실시간전용
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
# 데이터 수정 : loc[행,열]

df.loc[1,'Age'] = 31
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   31  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df['Age'] = df['Age'].astype(float)
df.dtypes
df
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob  31.0  Los Angeles
# 2  Charlie  35.0      Chicago
# 3    David  40.0      Houston

# %%
df_filtered = df[df['Age'] >= 35]
df_filtered
# Out:
#       Name   Age     City
# 2  Charlie  35.0  Chicago
# 3    David  40.0  Houston

# %%
df_filtered = df[(df['Age']>=30) & (df['City'] == 'Chicago')]
df_filtered
# Out:
#       Name   Age     City
# 2  Charlie  35.0  Chicago

# %%
arrays = [
    ['Group1', 'Group1', 'Group2', 'Group2'],
    ['Subgroup1', 'Subgroup2', 'Subgroup1', 'Subgroup2']
]

index = pd.MultiIndex.from_arrays(arrays, names= ('Group','Subgroup'))

data = {'Value' : [10,20,30,40]}
df_multi = pd.DataFrame(data, index = index)
df_multi
# Out:
#                   Value
# Group  Subgroup
# Group1 Subgroup1     10
#        Subgroup2     20
# Group2 Subgroup1     30
#        Subgroup2     40

# %%
df_multi.loc['Group1']
# Out:
#            Value
# Subgroup
# Subgroup1     10
# Subgroup2     20

# %%
df
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob  31.0  Los Angeles
# 2  Charlie  35.0      Chicago
# 3    David  40.0      Houston

# %%
print(df.loc[2,'Name'])
print(df.iloc[1,0])
print(df.at[2,'Name'])
print(df.iat[1,0])
# Out:
# Charlie
# Bob
# Charlie
# Bob

# %%
import pandas as pd

data = {
    'Name' : ['Alice','Bob','Charlie','David','Eve'],
    'Age' : [25,30,35,40,28],
    'City' : ['New York','Los Angeles','Chicago','Houston','San Francisco'],
    'Salary' : [70_000,80_000,120_000,90_000,75_000]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df.to_csv('data/data.csv',index=False)

# %%
#CSV 파일을 읽어올 때는 read_csv() 함수를 사용한다.

df = pd.read_csv("data/data.csv")
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df = pd.read_csv("data/data.csv",index_col='Name')
df
# Out:
#          Age           City  Salary
# Name
# Alice     25       New York   70000
# Bob       30    Los Angeles   80000
# Charlie   35        Chicago  120000
# David     40        Houston   90000
# Eve       28  San Francisco   75000

# %%
data = {
    'Name' : ['Alice','Bob','Charlie','David','Eve'],
    'Age' : [25,30,35,40,28],
    'City' : ['New York','Los Angeles','Chicago','Houston','San Francisco'],
    'Salary' : [70_000,80_000,120_000,90_000,75_000]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df.to_excel("data/output.xlsx",index= False,sheet_name='새 시트')

# %%
df = pd.read_excel("data/output.xlsx",sheet_name='새 시트')
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df.head(2)
# Out:
#     Name  Age         City  Salary
# 0  Alice   25     New York   70000
# 1    Bob   30  Los Angeles   80000

# %%
df.to_json("data/output.json")

# %%
df = pd.read_json("data/output.json")
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
from sqlalchemy import create_engine

# SQL 데이터베이스 연결
engine = create_engine('sqlite:///my_database.db')

# SQL 데이터베이스에 저장
df.to_sql('my_table', con=engine, if_exists='replace', index=False)

# SQL 쿼리로 데이터 읽기
df = pd.read_sql('SELECT * FROM my_table', con=engine)
print(df.head())
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
import pandas as pd
import numpy as np

data = {
    'Name' : ['Alice','Bob','Charlie','David','Eve'],
    'Age' : [25,30,np.nan,40,28],
    'City' : ['New York','Los Angeles','Chicago','Houston','San Francisco'],
    'Salary' : [70_000,80_000,120_000,90_000,np.nan]
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob  30.0    Los Angeles   80000.0
# 2  Charlie   NaN        Chicago  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco       NaN

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#     Name   Age         City   Salary
# 0  Alice  25.0     New York  70000.0
# 1    Bob  30.0  Los Angeles  80000.0
# 3  David  40.0      Houston  90000.0

# %%
df_filled = df.fillna(0)

# %%
import pandas as pd
import numpy as np

data = {
    'Name' : ['Alice','Bob','Charlie','David','Eve'],
    'Age' : [25,30,np.nan,40,28],
    'City' : ['New York','Los Angeles','Chicago','Houston','San Francisco'],
    'Salary' : [70_000,80_000,120_000,90_000,np.nan]
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob  30.0    Los Angeles   80000.0
# 2  Charlie   NaN        Chicago  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco       NaN

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#       Name    Age           City    Salary
# 0    Alice  25.00       New York   70000.0
# 1      Bob  30.00    Los Angeles   80000.0
# 2  Charlie  30.75        Chicago  120000.0
# 3    David  40.00        Houston   90000.0
# 4      Eve  28.00  San Francisco       NaN

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
df
# Out:
#       Name    Age           City    Salary
# 0    Alice  25.00       New York   70000.0
# 1      Bob  30.00    Los Angeles   80000.0
# 2  Charlie  30.75        Chicago  120000.0
# 3    David  40.00        Houston   90000.0
# 4      Eve  28.00  San Francisco   85000.0

# %%
data = {'Name': ['Alice', 'Bob', 'Alice', 'David'],
        'Age': [25, 30, 25, 40]}

df = pd.DataFrame(data)

# 중복값 확인
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 3  David   40

# %%
# Age를 기준으로 오름차순 정렬
df_sorted = df.sort_values(by='Age')
print(df_sorted,'\n')

# 내림차순 정렬
df_sorted_desc = df.sort_values(by='Age', ascending=False)
print(df_sorted_desc,'\n')

# 인덱스 기준으로 정렬
df_sorted_index = df.sort_index()
print(df_sorted_index)
# Out:
#     Name  Age
# 0  Alice   25
# 2  Alice   25
# 1    Bob   30
# 3  David   40
#
#     Name  Age
# 3  David   40
# 1    Bob   30
# 0  Alice   25
# 2  Alice   25
#
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  Alice   25
# 3  David   40

# %%
df_sorted_desc.sort_index(ascending= False, inplace= True)
df_sorted_desc
# Out:
#     Name  Age
# 3  David   40
# 2  Alice   25
# 1    Bob   30
# 0  Alice   25

# %%
data = {'Name': ['Alice', 'Bob', 'Alice', 'David'],
        'Age': [25, 30, 35, 40]}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  Alice   35
# 3  David   40

# %%
df.sort_values(by=["Name",'Age'], ascending = [False,True])
# Out:
#     Name  Age
# 3  David   40
# 1    Bob   30
# 0  Alice   25
# 2  Alice   35

# %%
df_filtered = df[df['Age'] >= 30]
df_filtered
# Out:
#     Name  Age
# 1    Bob   30
# 2  Alice   35
# 3  David   40

# %%
# Age가 30 이상이고, Name이 'Bob'인 데이터 필터링
df_filtered = df[(df['Age']>=30) & (df['Name']=='Bob')]
df_filtered
# Out:
#   Name  Age
# 1  Bob   30

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 90, 78, 92]
}

df = pd.DataFrame(data)
df['AdjustScore']= df['Score'].apply(lambda x: x + 10)
df
# Out:
#       Name  Score  AdjustScore
# 0    Alice     85           95
# 1      Bob     90          100
# 2  Charlie     78           88
# 3    David     92          102

# %%
# 성별 데이터 변환 예시
gender_data = pd.Series(['Male', 'Female', 'Female', 'Male'])

gender_numeric = gender_data.map(lambda x: 0 if x =='Male' else 1)
gender_numeric
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# dtype: int64

# %%
gender_data = pd.Series(['Male', 'Female', 'Female', 'Male'])

gender_numeric =gender_data.map({'Male' : 0, 'Female': 1})
gender_numeric
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# dtype: int64

# %%
# 두 개의 데이터프레임 생성
df1 = pd.DataFrame({'CustomerID': [1, 2, 3], 'Product': ['Laptop', 'Mouse', 'Keyboard']})
df2 = pd.DataFrame({'CustomerID': [2, 3, 4], 'Location': ['USA', 'Canada', 'Mexico']})

df_merged = pd.merge(df1,df2, on='CustomerID', how ='inner')
df_merged
# Out:
#    CustomerID   Product Location
# 0           2     Mouse      USA
# 1           3  Keyboard   Canada

# %%
df_merged = pd.merge(df1,df2, on='CustomerID', how ='left')
df_merged
# Out:
#    CustomerID   Product Location
# 0           1    Laptop      NaN
# 1           2     Mouse      USA
# 2           3  Keyboard   Canada

# %%
df_merged = pd.merge(df1,df2, on='CustomerID', how ='right')
df_merged
# Out:
#    CustomerID   Product Location
# 0           2     Mouse      USA
# 1           3  Keyboard   Canada
# 2           4       NaN   Mexico

# %%
df_merged = pd.merge(df1,df2, on='CustomerID', how ='outer')
df_merged
# Out:
#    CustomerID   Product Location
# 0           1    Laptop      NaN
# 1           2     Mouse      USA
# 2           3  Keyboard   Canada
# 3           4       NaN   Mexico

# %%
# 두 개의 데이터프레임을 세로로 연결
df1 = pd.DataFrame({'A': ['A0', 'A1'], 'B': ['B0', 'B1']})
df2 = pd.DataFrame({'A': ['A2', 'A3'], 'B': ['B2', 'B3']})

df_concat = pd.concat([df1,df2], axis=0)
df_concat
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3

# %%
df_concat = pd.concat([df1,df2], axis=0, ignore_index= True)
df_concat
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
df_concat = pd.concat([df1,df2], axis=1)
df_concat
# Out:
#     A   B   A   B
# 0  A0  B0  A2  B2
# 1  A1  B1  A3  B3

# %%
# 예시 데이터프레임 생성
df1 = pd.DataFrame({'A': ['A0', 'A1']}, index=['K0', 'K1'])
df2 = pd.DataFrame({'B': ['B0', 'B1']}, index=['K0', 'K1'])
df1
# Out:
#      A
# K0  A0
# K1  A1

# %%
df2
# Out:
#      B
# K0  B0
# K1  B1

# %%
df_join = df1.join(df2)
df_join
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1

# %%
# 피벗(pivot())

data = {'Date': ['2024-01-01', '2024-01-01', '2024-01-02'],
        'City': ['New York', 'Los Angeles', 'New York'],
        'Temperature': [55, 68, 52]}

df_weather = pd.DataFrame(data)

df_pivot = df_weather.pivot(index = "Date", columns= 'City', values= 'Temperature')
df_pivot
# Out:
# City        Los Angeles  New York
# Date
# 2024-01-01         68.0      55.0
# 2024-01-02          NaN      52.0

# %%
sales_data = {
    'Product': ['A', 'B', 'A', 'B'],
    'Sales': [100, 150, 200, 250],
    'Region': ['North', 'South', 'North', 'South']
}

df_sales = pd.DataFrame(sales_data)

df_pivot_table = df_sales.pivot_table(values = 'Sales', index = 'Region', columns= 'Product', aggfunc = 'sum')
df_pivot_table
# Out:
# Product      A      B
# Region
# North    300.0    NaN
# South      NaN  400.0

# %%
df_wide = pd.DataFrame({
    'ID': [1, 2, 3],
    'Math': [85, 90, 88],
    'English': [78, 85, 90]
})

# melt를 이용해 긴 형식으로 변환
df_melt = pd.melt(df_wide, id_vars=['ID'], value_vars=['Math', 'English'], var_name='Subject', value_name='Score')
print(df_melt)
# Out:
#    ID  Subject  Score
# 0   1     Math     85
# 1   2     Math     90
# 2   3     Math     88
# 3   1  English     78
# 4   2  English     85
# 5   3  English     90

# %%
import pandas as pd

data = {
    'Department': ['HR', 'IT', 'HR', 'Finance', 'IT', 'Finance'],
    'Salary': [50000, 60000, 52000, 80000, 65000, 90000]
}
df = pd.DataFrame(data)
df
# Out:
#   Department  Salary
# 0         HR   50000
# 1         IT   60000
# 2         HR   52000
# 3    Finance   80000
# 4         IT   65000
# 5    Finance   90000

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    85000.0
# HR         51000.0
# IT         62500.0
# Name: Salary, dtype: float64

# %%
data = {
    'Department': ['HR', 'IT', 'HR', 'Finance', 'IT', 'Finance'],
    'Location': ['New York', 'New York', 'Chicago', 'Chicago', 'New York', 'Chicago'],
    'Salary': [50000, 60000, 52000, 80000, 65000, 90000]
}
df = pd.DataFrame(data)

grouped = df.groupby(['Department','Location'])['Salary'].mean()
grouped
# Out:
# Department  Location
# Finance     Chicago     85000.0
# HR          Chicago     52000.0
#             New York    50000.0
# IT          New York    62500.0
# Name: Salary, dtype: float64

# %%
aggregated = df.groupby('Department').agg({
    'Salary': ['sum', 'mean', 'count']
})
print(aggregated)
# Out:
#             Salary
#                sum     mean count
# Department
# Finance     170000  85000.0     2
# HR          102000  51000.0     2
# IT          125000  62500.0     2

# %%
# 여러 집계 함수 적용
df.groupby('Department')['Salary'].agg(['sum', 'mean', 'min', 'max'])
# Out:
#                sum     mean    min    max
# Department
# Finance     170000  85000.0  80000  90000
# HR          102000  51000.0  50000  52000
# IT          125000  62500.0  60000  65000

# %%
# 평균 급여가 60000 이상인 부서만 선택
filtered = df.groupby('Department').filter(lambda x: x['Salary'].mean() >= 60000)
print(filtered)
# Out:
#   Department  Location  Salary
# 1         IT  New York   60000
# 3    Finance   Chicago   80000
# 4         IT  New York   65000
# 5    Finance   Chicago   90000

# %%
df
# Out:
#   Department  Location  Salary
# 0         HR  New York   50000
# 1         IT  New York   60000
# 2         HR   Chicago   52000
# 3    Finance   Chicago   80000
# 4         IT  New York   65000
# 5    Finance   Chicago   90000

# %%
unstacked = df.groupby(['Department','Location'])['Salary'].mean().unstack()
unstacked
# Out:
# Location    Chicago  New York
# Department
# Finance     85000.0       NaN
# HR          52000.0   50000.0
# IT              NaN   62500.0

# %%
stacked = unstacked.stack()
print(stacked)
# Out:
# Department  Location
# Finance     Chicago     85000.0
#             New York        NaN
# HR          Chicago     52000.0
#             New York    50000.0
# IT          Chicago         NaN
#             New York    62500.0
# dtype: float64

# %%
df
# Out:
#   Department  Location  Salary
# 0         HR  New York   50000
# 1         IT  New York   60000
# 2         HR   Chicago   52000
# 3    Finance   Chicago   80000
# 4         IT  New York   65000
# 5    Finance   Chicago   90000

# %%
df_reset = df.groupby(['Department'])['Salary'].mean().reset_index()
df_reset
# Out:
#   Department   Salary
# 0    Finance  85000.0
# 1         HR  51000.0
# 2         IT  62500.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 예시 데이터
data = {'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
        'Sales': [200, 300, 400, 500, 450]}
df = pd.DataFrame(data)

# 선 그래프 그리기
df.plot(x='Month', y='Sales', kind='line', title='Monthly Sales')
plt.show()

# %%
# 막대 그래프 그리기
df.plot(x='Month', y='Sales', kind='bar', title='Monthly Sales')
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Month'] + '2026')
df
# Out:
# C:\Users\UK\AppData\Local\Temp\ipykernel_25132\216583797.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Month'] + '2026')
#   Month  Sales       Date
# 0   Jan    200 2026-01-01
# 1   Feb    300 2026-02-01
# 2   Mar    400 2026-03-01
# 3   Apr    500 2026-04-01
# 4   May    450 2026-05-01

# %%
df.set_index('Date',inplace= True)
df
# Out:
#            Month  Sales
# Date
# 2026-01-01   Jan    200
# 2026-02-01   Feb    300
# 2026-03-01   Mar    400
# 2026-04-01   Apr    500
# 2026-05-01   May    450

# %%
monthly_sales = df.resample('ME').sum()
monthly_sales
# Out:
#            Month  Sales
# Date
# 2026-01-31   Jan    200
# 2026-02-28   Feb    300
# 2026-03-31   Mar    400
# 2026-04-30   Apr    500
# 2026-05-31   May    450

# %%
# 시계열 데이터 시각화
monthly_sales.plot(title='Monthly Sales Over Time')
plt.show()

# %%
df["RollingMean"]=df['Sales'].rolling(window = 3).mean()
df
# Out:
#            Month  Sales  RollingMean
# Date
# 2026-01-01   Jan    200          NaN
# 2026-02-01   Feb    300          NaN
# 2026-03-01   Mar    400        300.0
# 2026-04-01   Apr    500        400.0
# 2026-05-01   May    450        450.0

# %%
df[['Sales','RollingMean']].plot(title= 'Sales and 3-Month Rolling Average')
plt.show()
