# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key= OPENAI_API_KEY)

response = client.responses.create(
    model="gpt-5.6-luna",
    input="AI 최근 동향에 대해서 심도깊은 고찰을 하는중이다. 뭐가 요즘 핫한가?",
)

print(response.output_text)
# Out:
# 좋습니다. 2024년 상반기 기준으로 글로벌 AI 트렌드에서 특히 주목받는 흐름들을 핵심 축으로 정리해 드릴게요. 관심 산업이나 도메인이 있다면 더 구체적으로 맞춤 요약도 가능합니다.
#
# 핫 트렌드 요약 (카테고리별)
#
# 1) Foundation Models의 확장과 멀티모달/에이전트화
# - 거대 언어모델을 중심으로 텍스트를 넘어 이미지, 영상, 음성, 구조화된 데이터까지 통합한 멀티모달 모델이 확대되고 있습니다.
# - 모델 자체의 범용성뿐 아니라 에이전트 형태로 도구와 API를 연결해 자동화된 작업 수행을 하는 흐름이 강해지고 있습니다.
# - 비전-언어-행동이 결합된 시스템 설계가 보편화되며, 프롬프트 설계(프로세스) 대신 런타임에서의 도구 사용이 중요해지고 있습니다.
#
# 2) 오픈소스 LLM과 PEFT(프롬프트 엔지니어링 최소화) 전략의 부상
# - 오픈소스 LLM 생태계가 활발해지며 기업 데이터 프라이버시, 커스터마이징, 비용 관리 관점에서 매력도가 커졌습니다.
# - LoRA/QLoRA 같은 경량화 기법과 파인튜닝 시 프라이버시/안전 테스트를 병행하는 접근이 일반화되고 있습니다.
# - 벤처/연구기관이 안전성 검증과 평가 방법론을 함께 개발하는 흐름도 커짐.
#
# 3) RAG(검색 기반 생성)과 벡터 데이터베이스의 보편화
# - 내부 지식베이스나 외부 문서 컬렉션을 조회해 답변의 신뢰도를 높이는 RAG가 엔터프라이즈에서 표준 도구로 자리매김.
# - 벡터 DB, 문서 요약/인덱싱 파이프라인의 구축이 쉬워지면서 지식 관리와 고객 응대, 기술 지원 등에 활용 사례 증가.
#
# 4) AI 에이전트와 자동화 도구의 대중화
# - ChatGPT 계열의 에이전트에 의한 업무 자동화, 일정 관리, 도구 호출(코드 실행, 데이터 조회, 시스템 제어 등)이 확산.
# - LangChain, 에이전트 프레임워크, 메타데이터 관리 등 개발 인프라가 더 정교해짐.
# - 인간-AI 협업 설계의 중요성 증가: 신뢰성, 설명가능성, 의사결정 로그 관리 필요.
#
# 5) 효율성, 배포성, 인프라 최적화
# - 양자화(4-bit/8-bit), 희소성(sparsity), 어댑터/프롬프트 엔지니어링으로 추론 비용과 메모리 요구를 낮추는 기술이 실전에서 널리 쓰임.
# - 클라우드-온프레미스 하이브리드 배포, 모델 커스터마이즈를 위한 파이프라인 표준화가 발전.
# - 하드웨어 생태계(NVIDIA, AMD, 연구용 칩, 벤치마크)와 소프트웨어(라이브러리) 간 상호 운용성 개선.
#
# 6) 안전성, 거버넌스, 규제 대응의 강화
# - 허위 정보 생성 방지, 편향 완화, 프라이버시 보호, 저작권 이슈 등에 대한 규범화와 평가 체계가 점점 중요해짐.
# - 기업 내부의 위험 관리 프레임워크, 감사 로그, 안전성 벤치마크, 프라이버시 보호 설계 등이 의사결정의 핵심 기준으로 자리잡고 있음.
# - 각국 규제 및 산업 표준의 변화가 R&D 방향과 벤치마크 선택에 직접 영향.
#
# 7) 생성형 콘텐츠, 저작권·윤리 이슈의 확대
# - 합성 이미지/음성/동영상의 품질이 향상되면서 콘텐츠 저작권, 인물 초상권, 허위 콘텐츠에 대한 책임 소재 논의가 활발.
# - 이슈를 피하기 위한 데이터 소스 관리, 워터마크/저작인식 시스템, 윤리 가이드라인이 기업 운영에 반영.
#
# 8) 산업별 적용 사례의 다각화
# - 소프트웨어 개발: 코드 보조, 자동화된 코드 리뷰, 코드 검색의 효율화.
# - 고객지원/FAQ 자동화, 챗봇의 업무 프로세스 연계.
# - 제조/에너지/금융 등 현장 운영의 의사결정 지원과 자동화.
# - 연구·분석: 데이터 해석 보조, 가설 탐색, 시뮬레이션 요청 자동화.
#
# 한국/지역 트렌드 포커스
# - 개인정보 보호 및 데이터 거버넌스 강화에 발맞춘 프라이버시-중심 AI 운영 원칙 도입 증가.
# - 규제 환경 변화에 맞춘 기업의 AI 도입 로드맵 수립이 늘어나고, 공공 부문에서의 활용 사례도 확대되는 추세.
# - AI 인재 육성·교육, 스타트업의 기술 인프라 투자, 제조‧서비스 산업의 디지털 전환 가속화가 주목받음.
#
# 실무에 바로 쓰는 제안 포인트
# - 도메인 정의: 어떤 문제를 해결할 것인가(예: 정보 검색 자동화, 고객 응대 개선, 코드 개발 속도 향상 등).
# - 데이터 전략: 데이터 소스 확보 여부, 프라이버시/저작권 이슈, 벡터화 대상 문서의 품질.
# - 지표 설계: ROI, 비용/속도, 정확도, 사용성, 규제 준수 측정 지표 포함.
# - 파일럿 설계: 소규모 MVP로 가치 검증 → 확장 로드맵 수립.
# - 안전성 및 거버넌스: 위험 평가 매트릭스, 감사 로그, 사용자 피드백 루프 구축.
# - 운영 체계: 벤치마크/성능 모니터링 대시보드, 모델 업데이트 정책, 사고 대응 프로세스.
#
# 원하시면 더 구체적으로:
# - 특정 산업(의료, 금융, 제조, 소프트웨어 개발, 고객지원 등)이나 영역(데이터 프라이버시, 위험 관리, 규제 대응)에 맞춘 핫 이슈 요약과 벤치마크 목록, 도입 로드맵을 작성해 드리겠습니다.
# - 또한 간단한 1~2페이지 브리핑이나 슬라이드 구성안도 만들어 드릴 수 있어요. 어떤 형식이 필요하신지 알려주세요.
