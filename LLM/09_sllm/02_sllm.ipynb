# %% [markdown]
# # sLLM
#
# **소형 언어 모델(sLLM)**은 매개변수 수를 수십억에서 수백억 대로 제한하여, 대형 언어 모델(LLM)이 제공하는 핵심 기능을 유지하면서도 경량화·고효율화를 추구한 언어 모델이다.
#
# - **경량화**: 수십억~수백억 규모의 파라미터로 구성되어, LLM 대비 메모리·연산 요구량이 대폭 감소한다.
# - **비용 효율성**: 학습·추론 비용이 낮고, 전력 소모가 적어 온프레미스나 엣지 환경에서 활용하기 적합하다.
# - **실시간성**: 파라미터 수가 적어 추론 속도가 빠르며, 모바일·노트북·임베디스 환경에서도 운영 가능하다.
# - **도메인 특화**: 특정 분야 데이터로 미세조정(fine-tuning)하면 LLM과 유사한 성능을 달성할 수 있다.
#
# **1. 정의 및 분류**
#
# 소형 언어 모델은 파라미터 수가 수십억~수백억 대이며, 일반적으로 다음 세 가지 범주로 구분된다:
# - LLM(매개변수 ≥1천억): 최고 성능·높은 자원 요구
# - sLLM(수십~수백억): 성능·자원 효율 균형
# - sLM(수십억 이하): 단순 작업·극한 제약 환경 특화
#
# |구분   |파라미터 수       |주요 특징                         |
# |-------|------------------|-----------------------------------|
# |LLM    |≥1,000억          |최고 성능·고자원                  |
# |sLLM   |수십~수백억       |경량화·비용 효율성·응답 속도 우수 |
# |sLM    |수십억 이하       |극단적 경량화·제한적 기능         |
#
# **2. 주요 특징**
#
# 1. **경량화**
#    - 파라미터 수 감소로 모델 크기·메모리 점유율 최소화
#    - 예: TinyLlama는 11억 파라미터, 4비트 양자화 시 550 MB RAM 차지.
#
# 2. **비용·자원 효율성**
#    - GPU·클라우드 비용 절감
#    - 온프레미스·모바일 환경에서도 실시간 추론 가능.
#
# 3. **도메인 특화 및 미세조정**
#    - 한국어·금융·의료 등 특정 분야 데이터로 추가 학습해 고성능 발휘
#    - 예: beomi/Yi-Ko-6B(6 B 매개변수) 모델은 한국어·영어 병합 데이터로 학습되어 한국어 작업에서 우수한 성능 보유.
#
# 4. **응답 속도**
#    - 매개변수 수가 적어 LLM 대비 추론 속도 2~10배 향상
#
# **3. 대표적인 sLLM 사례**
#
# |모델명           |파라미터 수 |특징                                                         |
# |----------------|----------|-------------------------------------------------------------|
# |TinyLlama       |1.1 B     |Llama2 아키텍처 기반, FlashAttention 적용, 4비트 양자화 가능.   |
# |Yi-Ko-6B        |6 B       |한국어·영어 혼합 사전학습, 4 K 컨텍스트 길이, HuggingFace 지원.  |
# |Mistral 7B      |7.3 B     |영어·코딩 작업 특화, MMLU 60.1% 기록, Apache 2.0 라이선스 공개.    |
# |Phi-2           |2.7 B     |MS 온디바이스 AI용, 추론 최적화, 완전 오픈소스.             |
# |Motif 2.6B      |2.6 B     |국산 모델, Mistral 7B 대비 134% 우수 성능(지디넷).            |
#
# **4. 모델 구성 및 학습 기법**
#
# - **양자화(Quantization)**: 4~8비트 정밀도 사용으로 메모리 절감
# - **LoRA(Low-Rank Adaptation)**: 저차원 업데이트로 미세조정 시 메모리 효율 극대화
# - **지식 증류(Knowledge Distillation)**: LLM을 교사로 활용해 sLLM에 핵심 지식 전달.
# - **체인 오브 파이팅(CoT) 기법**: 단계별 추론 경로 최적화로 sLLM의 복잡 추론 능력 보완
#
# **5. 과제 및 한계**
#
# - **추론 능력**: 창의적·복합 문제 해결에서 LLM 대비 성능 격차 존재
# - **언어별 편향**: 한국어·소저자원 언어에서 데이터 부족 시 성능 저하 가능
# - **모델 안전성**: 판별 어려운 환각 위험 관리 필요

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# %pip install -Uqqq transformers huggingface_hub[hf_transfer] accelerate datasets openai python-dotenv typing_extensions
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

OPEN_API_KEY = os.environ('OPEN_API_KEY')
HF_TOKEN = os.environ('HF_TOKEN')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2
# ----> 3 OPEN_API_KEY = os.environ('OPEN_API_KEY')
#       4 HF_TOKEN = os.environ('HF_TOKEN')
#
# TypeError: '_Environ' object is not callable

# %% [markdown]
# ## meta-llama/Llama-3.2-3B-Instruct
# https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM        # 자동 토크나이저 / 생성모델
import torch

model_id = 'meta-llama/Llama-3.2-3B-Instruct'

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    dtype = torch.bfloat16,
    device_map = 'auto'
)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# GatedRepoError: 403 Client Error. (Request ID: Root=1-6a9e63f3-34dc39cc0983bee80054d343;72f4c5a0-38fc-45fd-8123-fcbeaab6f502)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Your request to access model meta-llama/Llama-3.2-3B-Instruct is awaiting a review from the repo authors.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct.
# 403 Client Error. (Request ID: Root=1-6a9e63f3-34dc39cc0983bee80054d343;72f4c5a0-38fc-45fd-8123-fcbeaab6f502)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Your request to access model meta-llama/Llama-3.2-3B-Instruct is awaiting a review from the repo authors.
#
# During handling of the above exception, another exception occurred:
#
# HTTPStatusError                           Traceback (most recent call last)
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\utils\hub.py:438, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     436 if len(full_filenames) == 1:
#     437     # This is slightly better for only 1 file
# --> 438     hf_hub_download(
#     439         path_or_repo_id,
#     440         filenames[0],
#     441         subfolder=None if len(subfolder) == 0 else subfolder,
#     442         repo_type=repo_type,
#     443         revision=revision,
#     444         cache_dir=cache_dir,
#     445         user_agent=user_agent,
#     446         force_download=force_download,
#     447         proxies=proxies,
#     448         token=token,
#     449         local_files_only=local_files_only,
#     450         tqdm_class=tqdm_class,
#     451     )
#     452 else:
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\huggingface_hub\file_download.py:1028, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#    1027 else:
# -> 1028     return _hf_hub_download_to_cache_dir(
#    1029         # Destination
#    1030         cache_dir=cache_dir,
#    1031         # File info
#    1032         repo_id=repo_id,
#    1033         filename=filename,
#    1034         repo_type=repo_type,
#    1035         revision=revision,
#    1036         # HTTP info
#    1037         endpoint=endpoint,
#    1038         etag_timeout=etag_timeout,
#    1039         headers=hf_headers,
#    1040         token=token,
#    1041         # Additional options
#    1042         local_files_only=local_files_only,
#    1043         force_download=force_download,
#    1044         tqdm_class=tqdm_class,
#    1045         dry_run=dry_run,
#    1046     )
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\huggingface_hub\file_download.py:1175, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1174     if head_call_error is not None:
# -> 1175         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1177 # From now on, etag, commit_hash, url and size are not None.
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\huggingface_hub\file_download.py:1915, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1910 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1911     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1912 ):
#    1913     # Repo not found or gated => let's raise the actual error
#    1914     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1915     raise head_call_error
#    1916 elif isinstance(head_call_error, FileMetadataError):
#    1917     # The call succeeded but the response lacked the metadata we need => a configuration issue, not connectivity.
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-6a9e63f3-51ff320951b98c87446ccf82;1c7a02bf-1f5c-4122-be8c-30094a0d902d)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Your request to access model meta-llama/Llama-3.2-3B-Instruct is awaiting a review from the repo authors.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 6
#       2 import torch
#       3
#       4 model_id = 'meta-llama/Llama-3.2-3B-Instruct'
#       5
# ----> 6 tokenizer = AutoTokenizer.from_pretrained(model_id)
#       7 model = AutoModelForCausalLM.from_pretrained(
#       8     model_id,
#       9     dtype = torch.bfloat16,
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\models\auto\tokenization_auto.py:777, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     773         config = AutoConfig.from_pretrained(
#     774             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     775         )
#     776     except (ValueError, OSError):
# --> 777         config = PreTrainedConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     779 config_model_type = config.model_type
#     780 config_model_name = config.model_name if hasattr(config, "model_name") else None
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\configuration_utils.py:706, in PreTrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     703 kwargs["local_files_only"] = local_files_only
#     704 kwargs["revision"] = revision
# --> 706 config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     707 if cls.base_config_key and cls.base_config_key in config_dict:
#     708     config_dict = config_dict[cls.base_config_key]
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\configuration_utils.py:747, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     745 original_kwargs = copy.deepcopy(kwargs)
#     746 # Get config dict associated with the base config file
# --> 747 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     748 if config_dict is None:
#     749     return {}, kwargs
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\configuration_utils.py:802, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     798 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     800 try:
#     801     # Load from local folder or from cache or download from model Hub and cache
# --> 802     resolved_config_file = cached_file(
#     803         pretrained_model_name_or_path,
#     804         configuration_file,
#     805         cache_dir=cache_dir,
#     806         force_download=force_download,
#     807         proxies=proxies,
#     808         local_files_only=local_files_only,
#     809         token=token,
#     810         user_agent=user_agent,
#     811         revision=revision,
#     812         subfolder=subfolder,
#     813         _commit_hash=commit_hash,
#     814     )
#     815     if resolved_config_file is None:
#     816         return None, kwargs
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\utils\hub.py:294, in cached_file(path_or_repo_id, filename, **kwargs)
#     239 def cached_file(
#     240     path_or_repo_id: str | os.PathLike,
#     241     filename: str,
#     242     **kwargs,
#     243 ) -> str | None:
#     244     """
#     245     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     246
#    (...)    292     ```
#     293     """
# --> 294     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     295     file = file[0] if file is not None else file
#     296     return file
#
# File ~\SKN\LLM\llm_venv\Lib\site-packages\transformers\utils\hub.py:511, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     509     if not _raise_exceptions_for_gated_repo:
#     510         return None
# --> 511     raise OSError(
#     512         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     513         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     514     ) from e
#     515 elif isinstance(e, LocalEntryNotFoundError):
#     516     if not _raise_exceptions_for_connection_errors:
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct.
# 403 Client Error. (Request ID: Root=1-6a9e63f3-51ff320951b98c87446ccf82;1c7a02bf-1f5c-4122-be8c-30094a0d902d)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Your request to access model meta-llama/Llama-3.2-3B-Instruct is awaiting a review from the repo authors.

# %%
model_device
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model_device
#
# NameError: name 'model_device' is not defined

# %%
# 프롬프트 토크나이징하여 모델 입력 후 생성 실행
prompt = 'Explain the theory of relativity in simple terms.'

# 토크나이징 : 파이토치 텐서형태 변환, 디바이스(GPU)로 이동
inputs = tokenizer(prompt,return_tensors = 'pt').to(moodel.device)
print(inputs)

outputs = model.generate(**inputs, max_length=1024) # 답변 생성
print(outputs)  # 토큰 ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 # 프롬프트 토크나이징하여 모델 입력 후 생성 실행
#       2 prompt = 'Explain the theory of relativity in simple terms.'
#       3
#       4 # 토크나이징 : 파이토치 텐서형태 변환, 디바이스(GPU)로 이동
# ----> 5 inputs = tokenizer(prompt,return_tensors = 'pt').to(moodel.device)
#       6 print(inputs)
#       7
#       8 outputs = model.generate(**inputs, max_length=1024) # 답변 생성
#
# NameError: name 'tokenizer' is not defined

# %%
# 토큰IDs -> 텍스트로 변환 (특수토큰 제거)

response = tokenizer.decode(outputs[0], skip_special_tokens = True)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 토큰IDs -> 텍스트로 변환 (특수토큰 제거)
#       2
# ----> 3 response = tokenizer.decode(outputs[0], skip_special_tokens = True)
#       4 print(response)
#
# NameError: name 'tokenizer' is not defined

# %%
def generate_by_sllm(prompt : str):
    inputs = tokenizer(prompt,return_tensors = 'pt').to(model.device)
    outputs = model.generate(**inputs, max_lenght=1024)
    return tokenizer.decode(outputs[0], skip_special_tokens = True)

print(generate_by_sllm("Hello How's the weather today?"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       2     inputs = tokenizer(prompt,return_tensors = 'pt').to(model.device)
#       3     outputs = model.generate(**inputs, max_lenght=1024)
#       4     return tokenizer.decode(outputs[0], skip_special_tokens = True)
#       5
# ----> 6 print(generate_by_sllm("Hello How's the weather today?"))
#
# Cell In[8], line 2, in generate_by_sllm(prompt)
#       1 def generate_by_sllm(prompt : str):
# ----> 2     inputs = tokenizer(prompt,return_tensors = 'pt').to(model.device)
#       3     outputs = model.generate(**inputs, max_lenght=1024)
#       4     return tokenizer.decode(outputs[0], skip_special_tokens = True)
#
# NameError: name 'tokenizer' is not defined

# %%
print(generate_by_sllm('안녕 만나서 반갑다. 오늘 저녁 뭐먹지?'))

# %% [markdown]
# ## Bllossom/llama-3.2-Korean-Bllossom-3B
#
# https://huggingface.co/Bllossom/llama-3.2-Korean-Bllossom-3B

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM        # 자동 토크나이저 / 생성모델
import torch

model_id = 'Bllossom/llama-3.2-Korean-Bllossom-3B'

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    dtype = torch.bfloat16,
    device_map = 'auto'
)

# %%
instruction = "철수가 20개의 연필을 가지고 있었는데 영희가 절반을 가져가고 민수가 남은 5개를 가져갔으면 철수에게 남은 연필의 갯수는 몇개인가요?"

# OpenAI 스타일 메시지 사용
messages = [
    {"role": "user", "content": f"{instruction}"}
]

# 채팅 템플릿 적용 으로 모델 입력 형태로 인코딩
input_ids = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True, # 어시스턴트 응답 생성 (생성 프롬프트를 기존 프롬프트 뒤에 추가)
    return_tensors="pt",
    return_dict = True
).to(model.device)

enc = {k:v.to(model.decvice) for k,v in input_ids.items()}

print(enc)      # 인코딩 텐서
print(tokenizer.decode(enc['input_ids'][0], skip_special_tokens=True))  # 디코딩

# %%
terminators = [
    tokenizer.convert_tokens_to_ids("<|end_of_text|>"), # 종료토큰
    tokenizer.convert_tokens_to_ids("<|eot_id|>")       # 대화 턴 종료
]

outputs = model.generate(
    **input_ids,    # 인코딩 dict를 키워드 인자로 언패킹해 전달
    max_new_tokens=1024,
    eos_token_id=terminators,   
    do_sample=True, # 샘플링 기반 생성
    temperature=0.6,    # 샘플링 창의성
    top_p=0.9   # 누적확률 기반 샘플링
)

prompt_len = enc['input_ids'].shape[-1]     # 입력 프롬프트 길이(토큰 수)
# 프롬프트 이후 생성된 부분만 디코딩
print(tokenizer.decode(outputs[0][prompt_len:], skip_special_tokens=True))

# %% [markdown]
# ## LGAI-EXAONE/EXAONE-4.0-1.2B
# https://huggingface.co/LGAI-EXAONE/EXAONE-4.0-1.2B

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "LGAI-EXAONE/EXAONE-4.0-1.2B"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="bfloat16",
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "너가 얼마나 대단한지 설명해 봐"

messages = [
    {"role": "user", "content": prompt}
]
input_ids = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
    return_dict = True
)

enc = {k:v.to(model.decvice) for k,v in input_ids.items()}


output = model.generate(
    **enc,
    max_new_tokens=128,
    do_sample=False,        # 샘플링 비활성화 (결정론적 답변)
)
print(tokenizer.decode(output[0], skip_special_tokens = True))

# %%
import os 
from openai import OpenAI

client = OpenAI(api_key = os.getenv('OPEN_API_KEY]'))

def generate_by_llm(prompt:str) -> str:
    response = client.response.create(
        model = 'gpt-5.6-luna',
        input = prompt,
        max_output_tokens = 1024
    )
    return response.output_text

print(generate_by_llm('Llama-3.2-3B-Instruct,llama-3.2-Korean-Bllossom-3B,EXAONE-4.0-1.2B 차이를 알려줘'))
