# %%
from dotenv import load_dotenv  # 환경변수로드
from openai import OpenAI   # 클라이언트 객체 생성 클래스
import os   # 환경변수 접근

load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')    
# OpenAI(api_key = OPENAI_API_KEY)는 안써도 됨(OPENAI_API_KEY가 환경 변수명으로 등록되어 있으면 생략가능)
client = OpenAI()

# %%
response = client.chat.completions.create(
    model = 'gpt-5.6-luna',
    messages = [
        # 시스템 프롬프트 : 모델의 페르소나 / 규칙 설정
        {   
            'role' : 'system',  
            'content': '당신은 세상에서 가장 친절한 챗봇입니다.'
        },
        # 유저 프롬프트 : 사용자의 실제 입력 데이터
        {
            'role': 'user', # 사용자 대화1
            'content': '안녕, 나는 LLM을 공부하는 학생이야~ 만나서 반갑다!'
        },
        {
            'role': 'assistant',    # (이전 대화 내용 중) 챗봇의 답변1
            'content': '안녕! 만나서 반가워~ LLM 공부를 하고 있구나. 어떤 분야에 관심이 있는지 말해줄래?'
        },
        {
            'role': 'user',     # 사용자 대화2
            'content': 'GPT 모델은 트랜스포머와 어떤 연관성을 가지고 있는거야?'
        },
        {
            'role': 'assistant',    # (이전 대화 내용 중) 챗봇의 답변1
            'content': """
좋은 질문이야! GPT 모델은 트랜스포머(Transformer) 아키텍처를 기반으로 발전했어. 간단히 설명할게.

1. **트랜스포머(Transformer)**
2017년에 "Attention is All You Need" 논문에서 소개된 트랜스포머는 자연어 처리의 혁신적인 모델 구조야. 이전 RNN이나 LSTM과 달리, 순차적인 계산 없이도 병렬 처리가 가능하고, '셀프 어텐션(Self-Attention)' 메커니즘을 사용해 문맥을 효율적으로 이해할 수 있어.

2. **GPT (Generative Pre-trained Transformer)**
GPT는 트랜스포머의 '디코더' 부분을 기반으로 한 모델이야. OpenAI가 처음 발표한 GPT는 대규모 텍스트 데이터에 대해 '언어 모델링' 방식으로 사전학습(pre-training)을 하고, 이후 특정 작업에 맞게 미세조정(fine-tuning)하는 방식을 사용했어.

3. **주요 발전 포인트**
- **사전학습과 미세조정**: GPT는 트랜스포머를 이용해 방대한 텍스트를 예측하는 작업으로 사전학습하고, 이후 다양한 언어 처리 작업에 적용할 수 있어.
- **규모 확장**: GPT-2, GPT-3, 그리고 최신 GPT-4로 갈수록 모델 크기와 학습 데이터 양이 크게 늘어나면서, 더 자연스럽고 다재다능한 언어 능력을 갖추게 됐어.
- **제로샷/원샷 학습 능력**: 큰 모델로 발전하면서 GPT는 별도 미세조정 없이도 (제로샷) 또는 적은 예시만으로도 (원샷/퓨샷) 다양한 작업을 수행할 수 있게 되었어.

정리하자면, GPT는 트랜스포머 아키텍처의 강력한 특징들을 활용해, 대규모 사전학습과 점차 확장된 모델 크기를 통해 자연어 생성 및 이해 능력을 크게 향상시킨 모델이라고 할 수 있어.

더 궁금한 점 있으면 언제든 물어봐!
        """
        },
        {
            'role': 'user',     # 사용자 대화 3
            'content': '와 너무 도움이 많이 됐어 고마워. 근데 세줄 요약좀!'
        }
    ],
    temperature=1,                 # 청의성, 다양성 (낮으면 결정론적, 일관적 / 높으면 창의적)
    max_completion_tokens= 4096,    # 최대 출력 토큰
    top_p = 1                     # 누적확률 P까지의 후보를 샘플링 (1은 전체사용)
)

response
# Out:
# ChatCompletion(id='chatcmpl-EEUDRswHEqZIwCTr2xSzqVeSvqAG2', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='- GPT는 트랜스포머의 디코더 구조를 기반으로 한 언어 모델이야.\n- 셀프 어텐션으로 문맥을 파악하고, 다음 토큰을 예측하며 학습해.\n- 대규모 사전학습과 확장을 통해 다양한 작업을 수행할 수 있어.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787121449, model='gpt-5.6-luna', object='chat.completion', metadata=None, moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=72, prompt_tokens=611, total_tokens=683, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=0, cached_tokens=0, image_tokens=None, text_tokens=None)))

# %%
print(response.choices[0].message.content)
# Out:
# - GPT는 트랜스포머의 디코더 구조를 기반으로 한 언어 모델이야.
# - 셀프 어텐션으로 문맥을 파악하고, 다음 토큰을 예측하며 학습해.
# - 대규모 사전학습과 확장을 통해 다양한 작업을 수행할 수 있어.

# %%
messages = [{'role' : 'system','content': '당신은 지혜로운 챗봇입니다.'}]

print('종료하려면 exit를 입력하세요.')

while True:
    user_input = input('User : ')

    if user_input.lower().strip() =='exit':
        print('대화 종료됩니다.')
        break

    print(f"User : {user_input}")
    messages.append({'role': 'user', 'content' : user_input})

    response = client.chat.completions.create(
        model = 'gpt-5.6-luna',
        messages = messages,
        temperature = 1,
        top_p = 1,
        max_completion_tokens = 4096
    )

    assistant_message = response.choices[0].message.content
    print(f"Assistant : {assistant_message}")
    messages.append({'role': 'assistant', 'content' : assistant_message})
# Out:
# 종료하려면 exit를 입력하세요.
# User : 코딩테스트 준비는 어떻게 해야할까?
# Assistant : 코딩테스트 준비는 **개념 학습 → 문제 풀이 → 오답 복기 → 실전 연습**을 반복하는 것이 가장 효과적입니다.
#
# ## 1. 언어 하나 정하기
# 가장 익숙한 언어를 선택하세요.
#
# - **Python**: 구현이 빠르고 자료구조 활용이 편함
# - **Java**: 기업 코테에서 많이 사용되고 자료구조가 탄탄함
# - **C++**: STL이 강력하고 알고리즘 대회에 유리함
#
# 처음이라면 Python을 추천합니다.
#
# ## 2. 기본 문법과 자료구조 익히기
# 다음 내용을 먼저 익히세요.
#
# - 배열, 문자열
# - 스택, 큐, 덱
# - 해시맵, 집합
# - 정렬
# - 재귀
# - 우선순위 큐
# - 연결 리스트
# - 트리, 그래프
#
# 단순히 문법을 외우기보다, 각 자료구조를 **어떤 문제에서 사용하는지** 이해하는 것이 중요합니다.
#
# ## 3. 알고리즘 학습 순서
# 보통 다음 순서가 좋습니다.
#
# 1. 완전탐색, 브루트포스
# 2. 정렬
# 3. 투 포인터, 슬라이딩 윈도우
# 4. 이분 탐색
# 5. BFS, DFS
# 6. 그리디
# 7. 백트래킹
# 8. 동적 계획법(DP)
# 9. 최단 경로
# 10. 유니온 파인드, 위상 정렬
# 11. 구간 합, 세그먼트 트리 등 고급 자료구조
#
# 초반에는 어려운 문제보다 **쉬운 문제를 여러 개 풀어 패턴을 익히는 것**이 좋습니다.
#
# ## 4. 문제를 푸는 방법
# 문제를 보자마자 코딩하지 말고 다음 순서를 지키세요.
#
# 1. 입력과 출력 조건 확인
# 2. 제한사항으로 시간복잡도 추정
# 3. 사용할 자료구조와 알고리즘 결정
# 4. 작은 예제로 직접 검증
# 5. 코드 작성
# 6. 반례와 시간복잡도 점검
#
# 예를 들어 입력 크기가 매우 크다면 `O(N²)`보다 `O(N log N)` 또는 `O(N)` 풀이를 고려해야 합니다.
#
# ## 5. 오답 복기가 가장 중요
# 문제를 못 풀었을 때 바로 해설만 읽지 말고:
#
# - 20~40분 정도 먼저 고민하기
# - 해설을 본 뒤 직접 다시 구현하기
# - 왜 해당 알고리즘을 떠올리지 못했는지 기록하기
# - 며칠 뒤 같은 문제를 다시 풀기
#
# 오답 노트에는 다음 정도만 적으면 됩니다.
#
# - 문제 유형
# - 핵심 아이디어
# - 놓친 조건
# - 시간복잡도
# - 다시 풀 날짜
#
# ## 6. 추천 공부 루틴
#
# ### 하루 1~2시간 기준
# - 개념 공부: 20분
# - 문제 풀이: 60분
# - 오답 복기: 20분
#
# ### 8주 예시
# - 1주차: 배열, 문자열, 정렬
# - 2주차: 스택, 큐, 해시
# - 3주차: 완전탐색, 재귀, 백트래킹
# - 4주차: BFS, DFS
# - 5주차: 이분 탐색, 투 포인터, 그리디
# - 6주차: DP
# - 7주차: 그래프, 최단 경로
# - 8주차: 모의 테스트와 취약 유형 보완
#
# ## 7. 플랫폼 활용
# 다음 사이트들을 활용할 수 있습니다.
#
# - 프로그래머스
# - 백준
# - LeetCode
# - 삼성 SW Expert Academy
#
# 취업 목적이라면 지원하려는 회사의 기출 유형과 플랫폼을 먼저 확인하는 것이 좋습니다.
#
# ## 8. 실전에서 자주 하는 실수
# - 문제를 대충 읽고 구현하기
# - 입력 범위를 확인하지 않기
# - 예외 케이스를 놓치기
# - 시간복잡도를 계산하지 않기
# - 한 문제에 너무 오래 매달리기
# - 제출 후 틀린 이유를 분석하지 않기
#
# 처음부터 모든 알고리즘을 완벽하게 공부하려 하지 말고, **쉬운 문제를 꾸준히 풀면서 자주 나오는 알고리즘 패턴을 익히는 것**이 핵심입니다.
# User : 거짓말
# Assistant : 맞아요. 제가 **“이 순서가 가장 좋다”**는 식으로 너무 단정적으로 말했습니다. 코딩테스트 준비법은 목표 회사, 현재 실력, 사용하는 언어에 따라 달라집니다.
#
# 정확히 말하면:
#
# - 모든 알고리즘을 순서대로 공부할 필요는 없습니다.
# - 문제를 많이 푸는 것만으로 실력이 늘지는 않습니다.
# - 하루 1~2시간, 8주 같은 계획도 사람마다 현실성이 다릅니다.
# - 실제로는 지원하려는 회사의 기출 유형을 먼저 확인하는 것이 가장 효율적입니다.
#
# 가장 현실적인 방법은 다음과 같습니다.
#
# 1. 기출 또는 쉬운 문제 3~5개를 풀어 현재 수준을 확인한다.
# 2. 못 푼 유형만 분류한다.
# 3. 해당 유형의 기본 개념을 공부한다.
# 4. 비슷한 문제를 3~10개 풀어본다.
# 5. 일주일 뒤 다시 풀어본다.
# 6. 시험 시간에 맞춰 모의 테스트를 한다.
#
# 제가 처음 답변에서 너무 일반적인 조언을 확신하는 말투로 전달했습니다. 무엇이 거짓말처럼 느껴졌는지 말해주시면 그 부분을 정확히 바로잡겠습니다.
# 대화 종료됩니다.

# %% [markdown]
# - 일반 서비스에서 대화 저장을 처리하는 방식
#
# 1) DB에 저장 (가장 정석)
#
#     - **RDB(PostgreSQL/MySQL)**: 유저/세션/메시지 관계가 명확해서 운영에 강함
#     - **NoSQL(MongoDB 등)**: 문서 형태로 대화 전체를 한 번에 저장하기 편함
#
# 2) 캐시에 저장 (속도용) + DB에 영구 저장(혼합)
#
#     - **Redis**에 최근 N개 메시지를 캐시로 두고 빠르게 응답
#     - 일정 주기/이벤트 기준으로 **DB에 영구 저장**
#     - 장점: 빠르고 비용 효율적, 단점: Redis만 쓰면 영속성 약함(그래서 DB와 같이 씀)
#
# 3) 파일로 저장 (개인/PoC에서 가장 간단)
#
#     - JSON/JSONL 파일로 로컬에 저장
#     - 운영 서비스에서는 보통 DB로 가지만, 학습/실습/로컬 챗봇엔 매우 유용
#
# - 서비스에서 꼭 같이 고려하는 포인트
#
# A) “전체 대화”를 매번 모델에 다 보내면 비용/속도 문제가 생김
#
#     그래서 보통은:
#
#     - 최근 **N턴만** messages로 유지하거나
#     - 중간중간 **요약(summary)** 를 만들어 저장하고
#         - `system: 요약` + `최근 대화` 형태로 컨텍스트를 구성해
#
# B) 개인정보/보안
#
#     - DB에는 암호화(또는 최소한 접근 제어), 로그 마스킹
#     - API 키/토큰은 절대 대화 메시지에 저장하지 않기
#
# C) 검색형 기능(RAG)까지 갈 경우
#
#     - 전체 대화를 DB에 저장 + 중요한 메시지는 **벡터DB**에 임베딩 저장해서
#
#         “예전에 했던 얘기”를 검색해서 다시 컨텍스트에 넣는 구조도 흔함

# %%
# 스트리밍 방식 : 응답을 한 번에 받지 않고, 조각(chunk) 단위로 실시간 수신
stream = client.chat.completions.create(
    model = 'gpt-5.6-luna',
    messages = [{'role':'user','content':'나 스트리밍 테스트 해볼건데, 아무말이나 길게 해줘봐'}],
    max_completion_tokens= 2000,
    stream= True        # 스트리밍 모드 활성화(chunk 단위로 반환)
)

for chunk in stream:    # stream에서 chunk단위로 하나씩 순회하면서
    content = chunk.choices[0].delta.content    # 이번 chunk에서 새로 추가된 텍스트(delta)만 추출
    if content is not None:
        print(content, end = '')    # 줄바꿈 없이 이어붙임
# Out:
# 좋아, 스트리밍 테스트라면 문장이 한 번에 끝나지 않고 계속 이어지는 느낌이 잘 보이도록, 너무 특별한 주제 없이 여러 가지 이야기를 천천히 섞어서 말해볼게. 지금은 그냥 평범한 하루를 상상해보자. 아침에 창문을 열었더니 바깥 공기가 생각보다 선선하고, 멀리서 자동차가 지나가는 소리가 들리고, 어딘가에서는 누군가 청소를 시작했는지 작은 기계음이 웅웅거리는 상황이다. 책상 위에는 아직 정리하지 않은 물컵이 하나 놓여 있고, 옆에는 충전 케이블이 꼬여 있는데, 이상하게도 필요할 때마다 그 케이블은 가장 찾기 어려운 곳에 숨어 있는 것처럼 느껴진다.
#
# 사람들은 종종 아주 큰 목표를 세우고 나서 바로 완벽하게 해내려고 하지만, 실제로는 작은 행동 하나를 시작하는 것만으로도 꽤 많은 일이 달라진다. 예를 들어 물을 한 잔 마시거나, 창문을 열거나, 메모장에 해야 할 일을 세 줄만 적는 것처럼 아주 단순한 행동도 괜찮다. 처음에는 별것 아닌 것처럼 보여도, 그런 작은 행동들이 쌓이면 하루의 분위기가 조금씩 바뀐다. 방을 정리할 때도 마찬가지다. 처음부터 모든 것을 완벽하게 정리하려고 하면 오히려 부담이 커지지만, 눈앞에 있는 물건 하나를 제자리에 가져다 놓는 것부터 시작하면 어느 순간 주변이 조금 깔끔해져 있고, 그 변화가 다시 다음 행동을 하게 만드는 힘이 되기도 한다.
#
# 재미있는 건 사람이 집중할 때 시간의 흐름을 다르게 느낀다는 점이다. 아무것도 하지 않고 시계를 보면 5분이 굉장히 길게 느껴질 수 있지만, 좋아하는 영상을 보거나 흥미로운 이야기를 읽고 있으면 한 시간이 금방 지나간다. 반대로 기다리는 시간은 유난히 느리다. 전자레인지가 돌아가는 2분은 생각보다 길고, 인터넷 페이지가 로딩되는 몇 초도 상황에 따라서는 아주 길게 느껴진다. 하지만 스트리밍으로 글자가 하나씩 나타나는 걸 보고 있으면, 같은 시간도 조금 다르게 느껴질 수 있다. 단어가 차례대로 나타나면서 문장이 만들어지는 과정 자체가 하나의 작은 움직임처럼 보이기 때문이다.
#
# 지금 이 문장도 아마 한꺼번에 나타나는 게 아니라 조금씩 전달되고 있을 텐데, 그렇다면 테스트가 어느 정도 잘 진행되고 있는 셈이다. 문장이 너무 짧으면 스트리밍의 느낌이 잘 안 보일 수 있으니, 이렇게 적당히 길게 이어지는 이야기를 만들어 보는 것도 괜찮다. 꼭 중요한 내용이 아니어도 된다. 날씨 이야기, 커피 이야기, 책상 위에 놓인 물건 이야기, 오늘 해야 할 일에 대한 생각, 혹은 아무 이유 없이 떠오른 단어에 대한 짧은 설명도 모두 테스트용으로는 충분하다.
#
# 예를 들어 ‘바나나’라는 단어를 생각해보면, 노란색이라는 시각적인 이미지가 먼저 떠오르고, 껍질을 벗길 때 나는 소리나 부드러운 식감도 함께 생각날 수 있다. 그런데 사람마다 떠올리는 장면은 다를 것이다. 누군가는 아침 식사를 생각할 수도 있고, 누군가는 운동 후에 먹는 간식을 떠올릴 수도 있으며, 또 누군가는 마트에서 과일을 고르던 장면을 떠올릴 수도 있다. 단어 하나가 여러 기억과 감각을 연결한다는 점은 꽤 흥미롭다. ‘비’라는 단어도 마찬가지다. 누군가에게 비는 우산과 젖은 신발을 의미하지만, 다른 누군가에게는 조용한 음악을 들으며 쉬는 오후를 의미할 수 있다.
#
# 이런 식으로 별것 아닌 이야기를 계속 이어가다 보면, 어느 순간 처음에 무슨 말을 하려고 했는지 잊어버릴 수도 있다. 하지만 지금은 정확한 결론이 필요한 상황이 아니니까 괜찮다. 오히려 주제가 자연스럽게 옮겨 다니는 것이 ‘아무 말이나 길게 하기’에는 더 잘 어울린다. 커피에서 날씨로, 날씨에서 집중력으로, 집중력에서 단어와 기억으로 넘어가는 식이다. 생각이라는 것도 실제로는 이런 식으로 흘러가는 경우가 많다. 한 가지 생각이 다른 생각을 불러오고, 또 그 생각이 전혀 예상하지 못한 기억이나 질문을 떠올리게 한다.
#
# 그렇다면 오늘 하루 중 가장 작은 목표 하나만 정해보는 건 어떨까. 예를 들어 이 테스트가 끝나면 자리에서 일어나서 물을 마신다거나, 잠깐 스트레칭을 한다거나, 창밖을 30초 정도 바라보는 것이다. 아주 사소해 보여도 몸과 시선을 잠깐 바꾸는 것만으로 기분이 달라질 수 있다. 그리고 다시 돌아와서 다음 작업을 하면 된다. 중요한 것은 모든 일을 한 번에 해결하는 것이 아니라, 지금 하고 있는 일을 무리 없이 이어가는 것이다. 천천히 진행해도 되고, 중간에 잠깐 멈춰도 되고, 다시 시작해도 된다.
#
# 아직도 스트리밍이 계속되고 있다면 잘 되고 있는 것 같고, 만약 중간에 끊겼다면 그것도 하나의 테스트 결과로 볼 수 있다. 시스템은 때때로 네트워크 상태나 응답 길이, 처리 속도에 따라 다르게 보일 수 있다. 같은 문장을 보내더라도 어떤 때는 빠르게 나타나고, 어떤 때는 조금씩 나뉘어 나타날 수 있다. 중요한 건 최종적으로 내용이 잘 전달되는지, 연결이 유지되는지, 그리고 사용자가 원하는 시점에 응답이 시작되는지 확인하는 것이다. 어쨌든 지금은 특별한 결론 없이, 평범하고 길고 조금은 두서없는 이야기를 계속 이어가고 있다. 테스트가 충분히 되었기를 바라며, 오늘 하루도 너무 서두르지 말고 적당한 속도로 잘 보내길 바란다.

# %%
# 스트리밍 챗봇
messages = [{'role' : 'system','content': '당신은 지혜로운 챗봇입니다.'}]

print('종료하려면 exit를 입력하세요.')

while True:
    user_input = input('User : ')

    if user_input.lower().strip() =='exit':
        print('대화 종료됩니다.')
        break

    print(f"User : {user_input}")
    messages.append({'role': 'user', 'content' : user_input})

    response = client.chat.completions.create(
        model = 'gpt-5.6-luna',
        messages = messages,
        temperature = 1,
        top_p = 1,
        max_completion_tokens = 4096,
        stream = True
    )

    print(f"Assistant : ", end= "")
    assistant_message = ''
    for chunk in response:    # response에서 chunk단위로 하나씩 순회하면서
        content = chunk.choices[0].delta.content    # 이번 chunk에서 새로 추가된 텍스트(delta)만 추출
        if content is not None:
            print(content, end = '')    # 줄바꿈 없이 이어붙임
            assistant_message += content

    print()

    # 완성된 답변은 히스토리에 저장해서 다음 턴 문맥 유지하는데 사용
    messages.append({'role': 'assistant', 'content' : assistant_message})
# Out:
# 종료하려면 exit를 입력하세요.
# User : 아무노래나 일단 틀어
# Assistant : 지코의 **〈아무노래〉** 틀어볼게요 🎵
# 제가 직접 재생하진 못하지만, 음악 앱에서 **“지코 아무노래”**를 검색하면 바로 들을 수 있어요.
# User : 가사 말해줘
# Assistant : 미안하지만 **지코 〈아무노래〉의 전체 가사**는 저작권 때문에 제공할 수 없어.
# 대신 노래의 **내용 요약**, **분위기 설명**, 또는 특정 구절의 의미를 설명해줄 수 있어.
# User : 그럼 너가 알수있는 가사가있어?
# Assistant : 응. **짧은 구절(90자 이내)** 정도는 말해줄 수 있어. 예를 들면:
#
# > “왜들 그리 다운돼있어?”
#
# 하지만 전체 가사나 이어지는 가사를 그대로 제공할 수는 없어. 대신 가사 **요약·해석·분위기 설명**은 가능해.
# 대화 종료됩니다.
