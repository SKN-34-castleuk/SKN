# %% [markdown]
# # Chatbot With MCP Server

# %%
# %pip install langchain-mcp-adapters mcp pywin32 -Uqqq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['TAVILY_API_KEY'] = os.getenv('TAVILY_API_KEY')

os.environ['LANGSMITH_TRACING'] = 'true'
os.environ['LANGSMITH_ENDPOINT'] = 'https://apac.api.smith.langchain.com'
os.environ['LANGSMITH_PROJECT'] = 'skn34-langchain'
os.environ['LANGSMITH_API_KEY'] = os.getenv('LANGSMITH_API_KEY')

# %% [markdown]
# ### MCP Server 연동
# - `http` 원격지의 MCP Server를 web 방식 호출
# - `stdio` MCP Client system에서 MCP Server구동하는 경우

# %%
# MultiServerMCPClient로 MCP서버 2개 연결 후 도구 목록 조회
from langchain_mcp_adapters.client import MultiServerMCPClient

CONTEXT7_API_KEY = os.getenv('CONTEXT7_API_KEY')

# MCP 서버설정 클라이언트
mcp_client = MultiServerMCPClient({
    # Langchain Docs MCP 서버
    "docs-langchain": {
        "url": "https://docs.langchain.com/mcp",  # 엔드포인트
        "transport": 'http'    # 전송 방식
    },
    # Context7 MCP 서버
    "context7": {
       "url": "https://mcp.context7.com/mcp",    # 엔드포인트
       "headers": {  # 인증정보를 담은 헤더
           "CONTEXT7_API_KEY": CONTEXT7_API_KEY
       },
       "transport": 'http'
    }
})

# get_tools는 비동기 메서드이므로 await로 동작 처리
mcp_tools = await mcp_client.get_tools()  # MCP 서버 Tool 목록 조회
mcp_tools
# Out:
# [StructuredTool(name='search_docs_by_lang_chain', description='Search across the Docs by LangChain knowledge base to find relevant information, code examples, API references, and guides. Use this tool when you need to answer questions about Docs by LangChain, find specific documentation, understand how features work, or locate implementation details. The search returns contextual content with titles and direct links to the documentation pages. If you need the full content of a specific page, use the query_docs_filesystem tool to `head` or `cat` the page path (append `.mdx` to the path returned from search — e.g. `head -200 /api-reference/create-customer.mdx`).', args_schema={'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'Search query'}}, 'required': ['query'], 'additionalProperties': False}, metadata={'title': None, 'readOnlyHint': True, 'destructiveHint': False, 'idempotentHint': True, 'openWorldHint': False}, handle_tool_error=<function _handle_mcp_tool_error at 0x000002634F036480>, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x0000026363416D40>),
#  StructuredTool(name='query_docs_filesystem_docs_by_lang_chain', description='Run a read-only shell-like query against a virtualized, in-memory filesystem rooted at `/` that contains ONLY the Docs by LangChain documentation pages and OpenAPI specs. This is NOT a shell on any real machine — nothing runs on the user\'s computer, the server host, or any network. The filesystem is a sandbox backed by documentation chunks.\n\nThis is how you read documentation pages: there is no separate "get page" tool. To read a page, pass its `.mdx` path (e.g. `/quickstart.mdx`, `/api-reference/create-customer.mdx`) to `head` or `cat`. To search the docs with exact keyword or regex matches, use `rg`. To understand the docs structure, use `tree` or `ls`.\n\n**Workflow:** Start with the search tool for broad or conceptual queries like "how to authenticate" or "rate limiting". Use this tool when you need exact keyword/regex matching, structural exploration, or to read the full content of a specific page by path.\n\nSupported commands: rg (ripgrep), grep, find, tree, ls, cat, head, tail, stat, wc, sort, uniq, cut, sed, awk, jq, plus basic text utilities. No writes, no network, no process control. Run `--help` on any command for usage.\n\nEach call is STATELESS: the working directory always resets to `/` and no shell variables, aliases, or history carry over between calls. If you need to operate in a subdirectory, chain commands in one call with `&&` or pass absolute paths (e.g., `cd /api-reference && ls` or `ls /api-reference`). Do NOT assume that `cd` in one call affects the next call.\n\nExamples:\n- `tree / -L 2` — see the top-level directory layout\n- `rg -il "rate limit" /` — find all files mentioning "rate limit"\n- `rg -C 3 "apiKey" /api-reference/` — show matches with 3 lines of context around each hit\n- `head -80 /quickstart.mdx` — read the top 80 lines of a specific page\n- `head -80 /quickstart.mdx /installation.mdx /guides/first-deploy.mdx` — read multiple pages in one call\n- `cat /api-reference/create-customer.mdx` — read a full page when you need everything\n- `cat /openapi/spec.json | jq \'.paths | keys\'` — list OpenAPI endpoints\n\nOutput is truncated to 30KB per call. Prefer targeted `rg -C` or `head -N` over broad `cat` on large files. To read only the relevant sections of a large file, use `rg -C 3 "pattern" /path/file.mdx`. Batch multiple file reads into a single `head` or `cat` call whenever possible.\n\nWhen referencing pages in your response to the user, convert filesystem paths to URL paths by removing the `.mdx` extension. For example, `/quickstart.mdx` becomes `/quickstart` and `/api-reference/overview.mdx` becomes `/api-reference/overview`.', args_schema={'type': 'object', 'properties': {'command': {'type': 'string', 'description': 'A shell command to run against the virtualized documentation filesystem (e.g., `rg -il "keyword" /`, `tree / -L 2`, `head -80 /path/file.mdx`).'}}, 'required': ['command'], 'additionalProperties': False}, metadata={'title': None, 'readOnlyHint': True, 'destructiveHint': False, 'idempotentHint': True, 'openWorldHint': False}, handle_tool_error=<function _handle_mcp_tool_error at 0x000002634F036480>, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x0000026363417CE0>),
#  StructuredTool(name='submit_feedback', description='Report a problem with this documentation site so the docs team can fix it. Use when a documentation page is incorrect, outdated, confusing, incomplete, or has a broken example. This is for feedback about the documentation content itself — not for product support requests or feedback about this tool or assistant.', args_schema={'type': 'object', 'properties': {'path': {'type': 'string', 'minLength': 1, 'description': 'The documentation page path the feedback is about (e.g., the page you were reading, such as `/quickstart`).'}, 'feedback': {'type': 'string', 'minLength': 1, 'description': 'A clear description of the documentation issue or suggestion — what is incorrect, outdated, missing, or confusing.'}}, 'required': ['path', 'feedback'], 'additionalProperties': False}, metadata={'title': None, 'readOnlyHint': False, 'destructiveHint': False, 'idempotentHint': False, 'openWorldHint': True}, handle_tool_error=<function _handle_mcp_tool_error at 0x000002634F036480>, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x0000026363416AC0>),
#  StructuredTool(name='resolve-library-id', description="Resolves a package/product name to a Context7-compatible library ID and returns matching libraries.\n\nYou MUST call this function before 'Query Documentation' tool to obtain a valid Context7-compatible library ID UNLESS the user explicitly provides a library ID in the format '/org/project' or '/org/project/version' in their query.\n\nEach result includes:\n- Library ID: Context7-compatible identifier (format: /org/project)\n- Name: Library or package name\n- Description: Short summary\n- Code Snippets: Number of available code examples\n- Source Reputation: Authority indicator (High, Medium, Low, or Unknown)\n- Benchmark Score: Quality indicator (100 is the highest score)\n- Versions: List of versions if available. Use one of those versions if the user provides a version in their query. The format of the version is /org/project/version.\n\nFor best results, select libraries based on name match, source reputation, snippet coverage, benchmark score, and relevance to your use case.\n\nSelection Process:\n1. Analyze the query to understand what library/package the user is looking for\n2. Return the most relevant match based on:\n- Name similarity to the query (exact matches prioritized)\n- Description relevance to the query's intent\n- Documentation coverage (prioritize libraries with higher Code Snippet counts)\n- Source reputation (consider libraries with High or Medium reputation more authoritative)\n- Benchmark Score: Quality indicator (100 is the highest score)\n\nResponse Format:\n- Return the selected library ID in a clearly marked section\n- Provide a brief explanation for why this library was chosen\n- If multiple good matches exist, acknowledge this but proceed with the most relevant one\n- If no good matches exist, clearly state this and suggest query refinements\n\nFor ambiguous queries, request clarification before proceeding with a best-guess match.\n\nIMPORTANT: Do not call this tool more than 3 times per question. If you cannot find what you need after 3 calls, use the best result you have.", args_schema={'type': 'object', '$schema': 'https://json-schema.org/draft/2020-12/schema', 'properties': {'query': {'type': 'string', 'description': "What to look up in the library's documentation. This is used to rank library results by relevance to what the user is trying to accomplish. The query is sent to the Context7 API for processing. Do not include any sensitive or confidential information such as API keys, passwords, credentials, personal data, or proprietary code in your query."}, 'libraryName': {'type': 'string', 'description': "Library name to search for and retrieve a Context7-compatible library ID. Use the official library name with proper punctuation — e.g., 'Next.js' instead of 'nextjs', 'Customer.io' instead of 'customerio', 'Three.js' instead of 'threejs'."}}, 'required': ['query', 'libraryName']}, metadata={'title': None, 'readOnlyHint': True, 'destructiveHint': False, 'idempotentHint': True, 'openWorldHint': True}, handle_tool_error=<function _handle_mcp_tool_error at 0x000002634F036480>, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x0000026363417A60>),
#  StructuredTool(name='query-docs', description="Retrieves and queries up-to-date documentation and code examples from Context7 for any programming library or framework.\n\nYou must call 'Resolve Context7 Library ID' tool first to obtain the exact Context7-compatible library ID required to use this tool, UNLESS the user explicitly provides a library ID in the format '/org/project' or '/org/project/version' in their query.\n\nDo not call this tool more than 3 times per question.", args_schema={'type': 'object', '$schema': 'https://json-schema.org/draft/2020-12/schema', 'properties': {'libraryId': {'type': 'string', 'description': "Exact Context7-compatible library ID (e.g., '/mongodb/docs', '/vercel/next.js', '/supabase/supabase', '/vercel/next.js/v14.3.0-canary.87') retrieved from 'resolve-library-id' or directly from user query in the format '/org/project' or '/org/project/version'."}, 'query': {'type': 'string', 'description': "What to look up in the library's documentation, scoped to a single concept. Be specific and include relevant details, but keep each query to one topic — if the user's question spans multiple distinct concepts, make a separate call per concept instead of combining them, unless the question is about how the concepts interact. Good: 'How to set up authentication with JWT in Express.js' or 'React useEffect cleanup function examples'. Bad (too vague): 'auth' or 'hooks'. Bad (too broad): 'routing and auth and caching in Next.js'. The query is sent to the Context7 API for processing. Do not include any sensitive or confidential information such as API keys, passwords, credentials, personal data, or proprietary code in your query."}}, 'required': ['libraryId', 'query']}, metadata={'title': None, 'readOnlyHint': True, 'destructiveHint': False, 'idempotentHint': True, 'openWorldHint': True}, handle_tool_error=<function _handle_mcp_tool_error at 0x000002634F036480>, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x0000026363416340>)]

# %%
from typing import TypedDict, Annotated, List     # 타입 힌트 도구
from langgraph.graph.message import add_messages  # 메시지 누적 처리를 해줄 헬퍼
from langchain.chat_models import init_chat_model
from langchain_tavily import TavilySearch

tavily_tool = TavilySearch(max_results=3)

# 그래프에서 사용할 상태(TypedDict) 스키마
class State(TypedDict):
    messages: Annotated[List, add_messages]  # messages 필드가 add_messages 규칙으로 누적 저장

llm = init_chat_model('gpt-5.4-mini')
tools = [tavily_tool] + mcp_tools
llm_with_tools = llm.bind_tools(tools)  # llm에 도구 스펙 파인딩

# State의 messages를 입력으로 받아, 응답 메시지를 추가해주는 노드 함수
def chatbot(state: State):
    response = llm_with_tools.invoke(state['messages'])  # 누적된 메시지 리스트로 LLM 호출
    return {'messages': [response]}  # add_messages 규칙에 의해 기존 messages에 응답이 누적됨

# %%
# langgraph.prebuilt 모듈의 ToolNode, tools_condition 함수 사용한 워크플로우
from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode, tools_condition

builder = StateGraph(State)  # State 스키마 기반 그래프 설계 객체 생성
tool_node = ToolNode(tools)

builder.add_edge(START, 'chatbot')  # 시작 노드 -> chatbot 노드

builder.add_node('chatbot', chatbot)  # chatbot 노드
builder.add_node('tools', tool_node)  # tools 노드

builder.add_conditional_edges('chatbot', tools_condition)
builder.add_edge('tools', 'chatbot')

graph = builder.compile()  # 설계된 워크프로우를 실행 가능한 그래프로 컴파일

graph  # 그래프 객체

# %%
from pprint import pprint

user_query = '최근 삼성전자와 하이닉스 주가는 어떻게 돼?'

state = {'messages': [('human', user_query)]}

response = graph.invoke(state)  # 그래프 실행 (START -> CHATBOT -> (tool 루프) or END)
pprint(response)
print("="*100)
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='최근 삼성전자와 하이닉스 주가는 어떻게 돼?', additional_kwargs={}, response_metadata={}, id='2c16d5c8-a0eb-4334-b64f-20840f235908'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 3173, 'total_tokens': 3227, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrLDGYe0yERsJs3HQAP2mhZjYBm9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06510-9db3-74d1-83bf-974085678392-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '삼성전자 하이닉스 주가 최근 한국 증시', 'search_depth': 'fast', 'topic': 'finance', 'time_range': 'week', 'include_images': False}, 'id': 'call_yG6GNHILh7WCwJ9VhnZcZls8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3173, 'output_tokens': 54, 'total_tokens': 3227, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="{'error': ValueError('Error 400: Finance topic is not supported for fast or ultra-fast search_depth.')}", name='tavily_search', id='a28325c1-6e20-4335-97b9-44adcb9d50ef', tool_call_id='call_yG6GNHILh7WCwJ9VhnZcZls8'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 3260, 'total_tokens': 3310, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrLFmk8w9LNml6sVjAsxNAhPe5By', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06510-a420-74b0-b72d-fc6fdaab7b6f-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '삼성전자 하이닉스 주가 최근 한국 증시', 'search_depth': 'advanced', 'topic': 'finance', 'time_range': 'week', 'include_images': False}, 'id': 'call_mBTqHTGy0kCgTUOSFtZtdeCL', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3260, 'output_tokens': 50, 'total_tokens': 3310, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='{"query": "삼성전자 하이닉스 주가 최근 한국 증시", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://m.blog.naver.com/vipro/224215976766", "title": "목표 주가 27만원 삼성전자·154만원 하이닉스? 지금 사면 진짜 늦은 걸까 : 네이버 블로그", "content": "Title: 목표 주가 27만원 삼성전자·154만원 하이닉스? 지금 사면 진짜 늦은 걸까 : 네이버 블로그\\n## 카테고리 이동 서울 자가에 사는 지델롱의 주담대 갚는 이야기. 목표 주가 27만원 삼성전자·154만원 하이닉스? 지금 사면 진짜 늦은 걸까. 최근 증권가에서 삼성전자 27만원, SK하이닉스 154만원 목표주가 전망이 다시 등장했다. 주가가 급락한 상황에서도 반도체 슈퍼사이클 기대 때문에 지금이 오히려 매수 구간이라는 분석이 나온다. 최근 국내 증시에서 가장 많이 들리는 숫자가 있다. 2026년 3월 증권사 리포트에서도 두 기업의 목표주가는 27만5000원과 154만원 수준으로 유지됐다. 흥미로운 점은 주가가 크게 흔들린 직후에도 이런 전망이 계속 나오고 있다는 것이다. 실제로 최근 중동 지정학 리스크로 코스피가 급락하면서. 삼성전자와 SK하이닉스 주가는 일주일 사이 10% 이상 하락하기도 했다. 삼성전자 27만, 하이닉스 154만이라는 전망을 유지하고 있을까. 최근 반도체 주가 폭락의 이유. 최근 반도체 주가가 흔들린 이유는 크게 두 가지다. 유가 급등과 글로벌 시장 충격 때문에 코스피가 크게 흔들렸고. 삼성전자와 SK하이닉스는 단기간에 크게 상승했던 종목이다. 이런 상황을 시장에서는 이렇게 부른다. 실적 전망이 전혀 변하지 않았기 때문이다. 삼성전자는 올해 영업이익이 200조 원 이상으로 증가할 것이라는 전망이 나오고 있다. SK하이닉스 역시 AI 메모리 수요 증가로. 지금 반도체 시장을 움직이는 핵심은 단 하나다. 메모리 반도체 수요도 함께 증가하고 있다. 이 시장은 더 커질 가능성이 높다. 그래서 글로벌 투자은행들도 목표주가를 계속 올리고 있다. AI 수요는 이미 숫자로 나타나고 있다. 반도체 기업 실적 전망도 크게 올라갔다. 일부 증권사에서는 두 기업의 영업이익 합계가. 300조 원 수준까지 늘어날 수 있다는 전망도 나온다. 한국 증시에서 가장 유명한 종목이다. 그래서 많은 투자자들이 이렇게 생각한다. 그래서 지금 투자자들이 고민해야 할 질문은 이것이다. AI 반도체 시장은 이제 막 시작된 산업이다. 메모리 수요는 더 증가할 가능성이 높다. 지금 반도체를 장기 사이클 초입으로 보고 있다. 지금 시장에서는 두 가지 숫자가 계속 반복된다. 지금 글로벌 AI 산업의 중심에는. 한국 기업 두 곳이 있다. 그래서 투자자들 사이에서는 이런 말이 나온다. 한국 반도체를 빼고 투자할 수 있을까?”. 아마 지금 시장의 가장 중요한 질문도. **코스피 6000 돌파 고수들이 보는 진짜 목표**. 폭락장 속에서도 외국인이 가장 많이 산 종목이 바로 삼성전자우였다. **10억 자산가들이 몰래 사는 국내주식**. 금융자산 10억 원 이상 한국 부자만 47만 명을 넘었다. 2026년 SK하이닉스 배당 정책은 사상 최대 실적을 바탕으로 확대되고 있지만, 실제로 연 50만원 배당을 ... **2026 SK하이닉스 주가 충격적 현실 \\"백만닉스\\" 체감 상승 vs 메모리 시장 변동 리스크**. 2026년 SK하이닉스는 장중 주가가 100만원 선을 뚫으며 ‘백만닉스 시대’가 열렸지만, 투자자들은 AI ... {\\"title\\":\\"목표 주가 27만원 삼성전자·154만원 하이닉스? 지금 사면 진짜 늦은 걸까\\",\\"source\\":\\"https://blog.naver.com/vipro/224215976766\\",\\"blogName\\":\\"서울 자가..\\",\\"domainIdOrBlogId\\":\\"vipro\\",\\"nicknameOrBlogId\\":\\"지델롱\\",\\"logNo\\":224215976766,\\"smartEditorVersion\\":4,\\"meDisplay\\":true,\\"lineDisplay\\":true,\\"outsideDisplay\\":true,\\"cafeDisplay\\":true,\\"blogDisplay\\":true}.", "score": 0.7803451, "raw_content": null, "id": "d53c13-00"}, {"url": "https://search.daum.net/search?w=tot&q=%ED%95%9C%EA%B5%AD+%EC%A6%9D%EC%8B%9C&rtmaxcoll=HSU&DA=HSU", "title": "한국 증시 – Daum 검색", "content": "Title: 한국 증시 – Daum 검색\\n# 다음. 전체선택됨 1일 1주 1개월 6개월 1년 직접입력옵션선택하기. 미국증시 중국 증시 일본 증시 삼성전자 주가 삼성전자 환율 홍콩증시 하이닉스 아시아 증시 달러 환율 삼성전자 우선주 시세 삼성전자 주식시세 유럽증시 한국 증시 전망 대만 증시 sk 하이닉스 금시세 인도증시 하이닉스 주가 삼성전기. 광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. 키움증권 최초 신규 비대면계좌 개설 고객이라면 10% 확률로 삼성전자 1주 드려요. 교보문고 www.kyobobook.co.kr. ****한국****증시**테마분석 교보문고KCSI 온라인서점 1위**. 주식 거래량, 시장전망, 이슈사항, 기업 공시 핵심 종목 분석 무료공유. 경제방송 출신 급등주 전문가실시간 시황분석 급등주 추출**. MTNW www.mtnw.co.kr. 대가의선택 www.masterpick.co.kr. 복잡한 경제 개념도 **한국****증시**, 쉽게! 경제 공부 막막했다면, 초보 눈높이 책으로 현명한 선택을 쿠팡에서! 1개월 10만원, 이용후기를 보고 결정하세요. *i*     광고노출기준은 검색어 연관성과 광고주의 입찰가입니다. | 항공사 | +6.39% | 7,244,841 | 135,420 | 상승대한항공 |. | 기계 | +2.82% | 188,610,513 | 1,830,825 | 상한가에이비프로바이오 |. | 조선 | +1.73% | 13,579,587 | 836,125 | 상승HD현대중공업 |. 코스피는 전장보다 447.57포인트(6.45%) 오른 7384.56에 장을 마쳤다. 반도체 업종 강세를 중심으로 국내 **증시**가 폭등하면서 글로벌 순위도 빠르게... gall.dcinside.com mgallery minjudang    톡으로 바로 공유   공유하기     [속보] **한국****증시** 영국 제치고 세계 8위 **증시** 우뚝 [속보] **한국****증시** 영국 제치고 세계 8위 **증시** 우뚝 사실 앞에 겸손한 민영 종합 뉴스통신사 www.news1.kr https://www.news1.kr/world/asia-australia/6151070   2026.04.28 웹문서 검색 더보기   대만·**한국** **증시**의 역사적 비상과 글로벌 순위 재편      clien.net board park    톡으로 바로 공유   공유하기     [속보] **한국****증시** 영국 제치고 세계 8위 **증시** 우뚝 : 클리앙 상보) | 뉴스1 대만의 시총이 4조4800억달러여서 **한국**이 조금만 더 랠리하면 대만도 추월할 전망이다. 2026.04.29 블로그 검색 더보기       economy-issue-today2.tistory.com 실시간 경제 이슈! 코스피 지수가 4일 만에 5% 넘게 오르면서 곧 7000선을 넘보고 있죠. 한국증시 상승세 외국인투자 MSCI 블랙록 선진국지수 AI기술 패시브자금유입 구조적변화 진입장벽완화   2026.05.05   코스피, 드디어 6500선 돌파! :   경기 용인시 기흥구 죽전로 10  복사하기복사. *i*  **서비스 안내**    ...
#               AIMessage(content='최근 시세를 바로 숫자로 확인하려면 실시간 주가 조회가 필요한데, 지금 검색 결과만으로는 정확한 현재가를 신뢰성 있게 못 잡았습니다.\n\n원하시면 제가 바로:\n1. **삼성전자**\n2. **SK하이닉스**\n\n각각의 **최근 종가 / 전일 대비 / 1주일 흐름** 기준으로 다시 찾아드릴게요.  \n또는 “**오늘 기준 현재가**”인지 “**최근 1주 추이**”인지 말씀해주시면 그 기준으로 정리해드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 128, 'prompt_tokens': 6631, 'total_tokens': 6759, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 3200, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrLIn7kurJ1ErCbdhhDF2qYXNC7m', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06510-b060-7e31-8760-ecbcabc9bcfc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6631, 'output_tokens': 128, 'total_tokens': 6759, 'input_token_details': {'audio': 0, 'cache_read': 3200}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ====================================================================================================
# 최근 시세를 바로 숫자로 확인하려면 실시간 주가 조회가 필요한데, 지금 검색 결과만으로는 정확한 현재가를 신뢰성 있게 못 잡았습니다.
#
# 원하시면 제가 바로:
# 1. **삼성전자**
# 2. **SK하이닉스**
#
# 각각의 **최근 종가 / 전일 대비 / 1주일 흐름** 기준으로 다시 찾아드릴게요.
# 또는 “**오늘 기준 현재가**”인지 “**최근 1주 추이**”인지 말씀해주시면 그 기준으로 정리해드리겠습니다.

# %%
user_query = 'langchain 최신버전에서 새롭게 추가된 부분은? langchain MCP 사용해줘'

state = {'messages': [('human', user_query)]}

response = await graph.ainvoke(state)  # 그래프 비동기 실행
pprint(response)
print("="*100)
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='langchain 최신버전에서 새롭게 추가된 부분은? langchain MCP 사용해줘', additional_kwargs={}, response_metadata={}, id='9c348b00-431a-4dbe-bda1-93a7b8e7c53b'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 3178, 'total_tokens': 3216, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrPDbRxCT9DhOamTRvyLmnrOBsVB', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06514-65ec-7463-8468-933780d11d95-0', tool_calls=[{'name': 'resolve-library-id', 'args': {'libraryName': 'LangChain', 'query': 'latest changes and new features in LangChain, especially MCP support and recent additions'}, 'id': 'call_ay7yMB3tuU8GtJKaayDDyEEP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3178, 'output_tokens': 38, 'total_tokens': 3216, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content=[{'type': 'text', 'text': 'Available Libraries:\n\n- Title: LangChain\n- Context7-compatible library ID: /websites/langchain\n- Description: LangChain is a platform for agent engineering, offering open-source frameworks in Python and TypeScript to build reliable AI agents, alongside LangSmith for continuous testing and improvement.\n- Code Snippets: 26745\n- Source Reputation: High\n- Benchmark Score: 73.56\n----------\n- Title: LangChain\n- Context7-compatible library ID: /websites/langchain_oss_python_langchain\n- Description: LangChain is an open-source framework with a pre-built agent architecture and integrations for models and tools, designed to help developers build agents and applications powered by LLMs.\n- Code Snippets: 1710\n- Source Reputation: High\n- Benchmark Score: 80.67\n----------\n- Title: LangChain\n- Context7-compatible library ID: /websites/langchain_oss\n- Description: LangChain is an open source framework for building agents and LLM-powered applications with pre-built agent architecture, model integrations, and tools for rapid development.\n- Code Snippets: 20458\n- Source Reputation: High\n- Benchmark Score: 69.2\n----------\n- Title: LangChain Reference\n- Context7-compatible library ID: /websites/reference_langchain\n- Description: Unified API reference documentation for LangChain, LangGraph, Deep Agents, LangSmith, and integrations across Python and JavaScript packages.\n- Code Snippets: 30608\n- Source Reputation: High\n- Benchmark Score: 68.04\n----------\n- Title: LangChain Documentation\n- Context7-compatible library ID: /langchain-ai/docs\n- Description: This repository contains the documentation build pipeline for LangChain projects, converting markdown and notebook files into a format suitable for Mintlify documentation sites.\n- Code Snippets: 23272\n- Source Reputation: High\n- Benchmark Score: 74.76', 'id': 'lc_ec15e394-9092-47a9-ae33-517d617f6417'}], name='resolve-library-id', id='14ae12e7-771f-4de7-b089-cda2f097ae96', tool_call_id='call_ay7yMB3tuU8GtJKaayDDyEEP'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 3624, 'total_tokens': 3684, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrPI00j61QoxzxBqD6i3rDLIPBe6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06514-78ed-76f1-92b1-e361a4e997e8-0', tool_calls=[{'name': 'query-docs', 'args': {'libraryId': '/websites/langchain_oss', 'query': 'What is new in the latest LangChain release, and what MCP support was added? Summarize recent additions and give examples of using MCP with LangChain.'}, 'id': 'call_i2uoJHLrI3xtmbxXiAsSWsd0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3624, 'output_tokens': 60, 'total_tokens': 3684, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content=[{'type': 'text', 'text': '### Install langchain-mcp-adapters\n\nSource: https://docs.langchain.com/oss/python/deepagents/mcp\n\nInstallation commands for the MCP adapter library using pip or uv.\n\n```bash\npip install langchain-mcp-adapters\n```\n\n```bash\nuv add langchain-mcp-adapters\n```\n\n--------------------------------\n\n### Retrieve and load MCP tools\n\nSource: https://docs.langchain.com/oss/python/langchain/mcp\n\nUse client.get_tools() to fetch tools from MCP servers for use in LangChain agents.\n\n```python\nfrom langchain_mcp_adapters.client import MultiServerMCPClient\nfrom langchain.agents import create_agent\n\nclient = MultiServerMCPClient({...})\ntools = await client.get_tools()  # [!code highlight]\nagent = create_agent("claude-sonnet-4-6", tools)\n```\n\n--------------------------------\n\n### Retrieve and Use MCP Tools\n\nSource: https://docs.langchain.com/oss/javascript/deepagents/mcp\n\nRetrieves tools from an MCP server and integrates them into a LangChain agent.\n\n```typescript\nimport { MultiServerMCPClient } from "@langchain/mcp-adapters";\nimport { createAgent } from "langchain";\n\nconst client = new MultiServerMCPClient({...});\nconst tools = await client.getTools();\nconst agent = createAgent({ model: "claude-sonnet-4-6", tools });\n```\n\n### langchain v1.1.0\n\nSource: https://docs.langchain.com/oss/python/langgraph/changelog-py\n\nLangChain v1.1.0 introduces model profiles, which allow chat models to expose their supported features and capabilities via a .profile attribute. This data powers new functionality, including context-aware summarization middleware and the ability to infer native structured output support. Additionally, the release adds support for SystemMessage instances in agent creation, automated model retry middleware with exponential backoff, and content moderation middleware for detecting unsafe interactions.\n\n--------------------------------\n\n### LangChain integrations\n\nSource: https://docs.langchain.com/oss/python/reference/integrations-python\n\nLangChain supports the Model Context Protocol (MCP), enabling external tools to work with LangChain and LangGraph applications through a standard interface. To use MCP tools, refer to `langchain-mcp-adapters`.', 'id': 'lc_a9d4cf05-f1e2-41f4-a02a-629bc97273c0'}], name='query-docs', id='1b6cb217-9ed1-4bb1-a382-61bfbff2a724', tool_call_id='call_i2uoJHLrI3xtmbxXiAsSWsd0'),
#               AIMessage(content='네. 최신 LangChain에서는 **MCP(Model Context Protocol) 지원이 추가**되어, 외부 MCP 서버의 도구들을 LangChain 에이전트에 바로 연결할 수 있습니다.\n\n핵심 추가점만 요약하면:\n\n- **MCP 통합 지원**\n  - `langchain-mcp-adapters` 패키지를 통해 MCP 서버의 tool을 불러와 사용 가능\n- **멀티 서버 연결**\n  - `MultiServerMCPClient`로 여러 MCP 서버에서 도구를 모아 사용 가능\n- **에이전트 연결이 간단함**\n  - 가져온 tools를 `create_agent(...)`에 그대로 넣어서 사용\n\n예시:\n\n```python\nfrom langchain_mcp_adapters.client import MultiServerMCPClient\nfrom langchain.agents import create_agent\n\nclient = MultiServerMCPClient({...})\ntools = await client.get_tools()\nagent = create_agent("claude-sonnet-4-6", tools)\n```\n\n설치:\n\n```bash\npip install langchain-mcp-adapters\n# 또는\nuv add langchain-mcp-adapters\n```\n\n추가로 최신 버전 쪽 주요 변화도 보면:\n\n- **model profiles** 도입: 모델이 지원하는 기능을 `.profile`로 노출\n- **context-aware summarization middleware**\n- **native structured output 지원 추론**\n- **SystemMessage 기반 agent 생성 지원**\n- **자동 retry middleware**\n- **content moderation middleware**\n\n원하시면 제가 다음 중 하나로 바로 이어서 정리해드릴게요:\n\n1. **LangChain 최신 변경점 전체 요약**\n2. **MCP를 LangChain에서 실제로 붙이는 예제**\n3. **Python / TypeScript 둘 다 MCP 예제**\n4. **내 MCP 서버를 LangChain agent에 연결하는 방법**', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 384, 'prompt_tokens': 4164, 'total_tokens': 4548, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 3200, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrPNsIdIasL4VzF2jFisgalAxFhs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06514-8cf0-7921-adc5-e5cfddec7daf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4164, 'output_tokens': 384, 'total_tokens': 4548, 'input_token_details': {'audio': 0, 'cache_read': 3200}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ====================================================================================================
# 네. 최신 LangChain에서는 **MCP(Model Context Protocol) 지원이 추가**되어, 외부 MCP 서버의 도구들을 LangChain 에이전트에 바로 연결할 수 있습니다.
#
# 핵심 추가점만 요약하면:
#
# - **MCP 통합 지원**
#   - `langchain-mcp-adapters` 패키지를 통해 MCP 서버의 tool을 불러와 사용 가능
# - **멀티 서버 연결**
#   - `MultiServerMCPClient`로 여러 MCP 서버에서 도구를 모아 사용 가능
# - **에이전트 연결이 간단함**
#   - 가져온 tools를 `create_agent(...)`에 그대로 넣어서 사용
#
# 예시:
#
# ```python
# from langchain_mcp_adapters.client import MultiServerMCPClient
# from langchain.agents import create_agent
#
# client = MultiServerMCPClient({...})
# tools = await client.get_tools()
# agent = create_agent("claude-sonnet-4-6", tools)
# ```
#
# 설치:
#
# ```bash
# pip install langchain-mcp-adapters
# # 또는
# uv add langchain-mcp-adapters
# ```
#
# 추가로 최신 버전 쪽 주요 변화도 보면:
#
# - **model profiles** 도입: 모델이 지원하는 기능을 `.profile`로 노출
# - **context-aware summarization middleware**
# - **native structured output 지원 추론**
# - **SystemMessage 기반 agent 생성 지원**
# - **자동 retry middleware**
# - **content moderation middleware**
#
# 원하시면 제가 다음 중 하나로 바로 이어서 정리해드릴게요:
#
# 1. **LangChain 최신 변경점 전체 요약**
# 2. **MCP를 LangChain에서 실제로 붙이는 예제**
# 3. **Python / TypeScript 둘 다 MCP 예제**
# 4. **내 MCP 서버를 LangChain agent에 연결하는 방법**

# %%
user_query = '웹 프론트엔드 개발시 필요한 패키지 또는 라이브러리가 뭐야? mcp 사용해서 검색해줘'

state = {'messages': [('human', user_query)]}

response = await graph.ainvoke(state)  # 그래프 비동기 실행
pprint(response)
print("="*100)
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='웹 프론트엔드 개발시 필요한 패키지 또는 라이브러리가 뭐야? mcp 사용해서 검색해줘', additional_kwargs={}, response_metadata={}, id='e45c78a2-b168-4402-9e72-d96afb237d91'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 3186, 'total_tokens': 3243, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrSYDWt8wKylr1zr1OyuWU0BqRUT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06517-8b98-7702-a7ab-45e802065696-0', tool_calls=[{'name': 'resolve-library-id', 'args': {'libraryName': 'Next.js', 'query': 'web frontend development commonly used packages and libraries for React/Next.js frontend stack, including routing, state management, forms, styling, data fetching, testing, and build tools'}, 'id': 'call_MJQ1ozQ3okrQMeQ22BsX7N4R', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3186, 'output_tokens': 57, 'total_tokens': 3243, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content=[{'type': 'text', 'text': 'Available Libraries:\n\n- Title: Next.js\n- Context7-compatible library ID: /vercel/next.js\n- Description: Next.js enables you to create full-stack web applications by extending the latest React features and integrating powerful Rust-based JavaScript tooling for the fastest builds.\n- Code Snippets: 5587\n- Source Reputation: High\n- Benchmark Score: 89.01\n- Versions: v14.3.0-canary.87, v13.5.11, v15.1.8, v15.4.0-canary.82, v12.3.7, v11.1.3, v16.0.3, __branch__01-02-copy_58398, v16.1.0, v16.1.1, v15.1.11, v16.1.5, v16.1.6, v16.2.2, __branch__15-6-0-canary-57, v16.2.9\n----------\n- Title: Next.js\n- Context7-compatible library ID: /websites/nextjs\n- Description: Next.js is a React framework for building full-stack web applications. It provides additional features and optimizations, automatically configuring lower-level tools to help developers focus on building products quickly.\n- Code Snippets: 5214\n- Source Reputation: High\n- Benchmark Score: 85.65\n----------\n- Title: Next.js Boilerplate\n- Context7-compatible library ID: /ixartz/next-js-boilerplate\n- Description: A production-ready Next.js starter template with App Router, TypeScript, Tailwind CSS, authentication, database ORM, testing, and comprehensive developer tools.\n- Code Snippets: 448\n- Source Reputation: High\n- Benchmark Score: 58.58\n----------\n- Title: Next.js Auth0\n- Context7-compatible library ID: /auth0/nextjs-auth0\n- Description: The Auth0 Next.js SDK is a library for implementing user authentication in Next.js applications, providing seamless integration with Auth0 for secure user management.\n- Code Snippets: 1022\n- Source Reputation: High\n- Benchmark Score: 85.51\n----------\n- Title: Sentry Next.js\n- Context7-compatible library ID: /websites/sentry_io_platforms_javascript_guides_nextjs\n- Description: Learn how to set up and configure Sentry in your Next.js application using the installation wizard, capture your first errors, logs and traces, and view them in Sentry.\n- Code Snippets: 1818\n- Source Reputation: High\n- Benchmark Score: 77.27', 'id': 'lc_dc027cc2-48a3-4af6-abaa-2b06e8e21be1'}], name='resolve-library-id', id='f3c4d2fb-234c-4b74-b96f-01b41c0c35a9', tool_call_id='call_MJQ1ozQ3okrQMeQ22BsX7N4R'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 3805, 'total_tokens': 3862, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 3200, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrSc0cG4OPAuwoecn1qPQSfn7UJu', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06517-a0b3-7791-ad9b-2d5eeb8bde8c-0', tool_calls=[{'name': 'query-docs', 'args': {'libraryId': '/vercel/next.js', 'query': 'recommended frontend libraries and packages for a modern web application stack: routing, state management, forms, styling, data fetching, testing, icons, and validation'}, 'id': 'call_W1hcznUJhBMrcl4OxF6CBtvw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3805, 'output_tokens': 57, 'total_tokens': 3862, 'input_token_details': {'audio': 0, 'cache_read': 3200}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content=[{'type': 'text', 'text': "### Install Next.js and React dependencies\n\nSource: https://github.com/vercel/next.js/blob/canary/docs/01-app/01-getting-started/01-installation.mdx\n\nInstalls the latest versions of Next.js, React, and React DOM using your preferred package manager. React and react-dom should be declared for ecosystem and tooling compatibility.\n\n```bash\npnpm i next@latest react@latest react-dom@latest\n```\n\n```bash\nnpm i next@latest react@latest react-dom@latest\n```\n\n```bash\nyarn add next@latest react@latest react-dom@latest\n```\n\n```bash\nbun add next@latest react@latest react-dom@latest\n```\n\n--------------------------------\n\n### Client-side Data Fetching with SWR in React\n\nSource: https://github.com/vercel/next.js/blob/canary/docs/02-pages/03-building-your-application/03-data-fetching/05-client-side.mdx\n\nThis snippet shows how to use the SWR library for client-side data fetching. SWR simplifies data fetching by providing automatic caching, revalidation, and streamlined state management.\n\n```jsx\nimport useSWR from 'swr'\n\nconst fetcher = (...args) => fetch(...args).then((res) => res.json())\n\nfunction Profile() {\n  const { data, error } = useSWR('/api/profile-data', fetcher)\n\n  if (error) return <div>Failed to load</div>\n  if (!data) return <div>Loading...</div>\n\n  return (\n    <div>\n      <h1>{data.name}</h1>\n      <p>{data.bio}</p>\n    </div>\n  )\n}\n```\n\n--------------------------------\n\n### Fetching data with SWR in a Client Component\n\nSource: https://github.com/vercel/next.js/blob/canary/docs/01-app/01-getting-started/06-fetching-data.mdx\n\nUse the SWR library to handle client-side data fetching, caching, and loading states.\n\n```tsx\n'use client'\nimport useSWR from 'swr'\n\nconst fetcher = (url) => fetch(url).then((r) => r.json())\n\nexport default function BlogPage() {\n  const { data, error, isLoading } = useSWR(\n    'https://api.vercel.app/blog',\n    fetcher\n  )\n\n  if (isLoading) return <div>Loading...</div>\n  if (error) return <div>Error: {error.message}</div>\n\n  return (\n    <ul>\n      {data.map((post: { id: string; title: string }) => (\n        <li key={post.id}>{post.title}</li>\n      ))}\n    </ul>\n  )\n}\n```\n\n```jsx\n'use client'\n\nimport useSWR from 'swr'\n\nconst fetcher = (url) => fetch(url).then((r) => r.json())\n\nexport default function BlogPage() {\n  const { data, error, isLoading } = useSWR(\n    'https://api.vercel.app/blog',\n    fetcher\n  )\n\n  if (isLoading) return <div>Loading...</div>\n  if (error) return <div>Error: {error.message}</div>\n\n  return (\n    <ul>\n      {data.map((post) => (\n        <li key={post.id}>{post.title}</li>\n      ))}\n    </ul>\n  )\n}\n```\n\n--------------------------------\n\n### <Link>\n\nSource: https://github.com/vercel/next.js/blob/canary/docs/01-app/03-api-reference/02-components/link.mdx\n\nA React component that extends the HTML <a> element to provide prefetching and client-side navigation between routes in Next.js applications.\n\n```APIDOC\n## `<Link>`\n\n### Description\nExtends HTML `<a>` element with client-side navigation, prefetching, and transition options.\n\n### Props\n\n- **href** (`string` | `object`) - Required - The path or URL to navigate to.\n- **locale** (`string` | `false`) - Optional - The active locale is automatically prepended. Setting `locale` allows providing a different locale, or setting to `false` disables default prepending.\n- **as** (`string`) - Optional - Decorator for the path that will be shown in the browser URL bar.\n- **onNavigate** (`(e: { preventDefault: () => void }) => void`) - Optional - Event handler called during client-side navigation. Allows preventing navigation via `e.preventDefault()`.\n- **transitionTypes** (`string[]`) - Optional - A list of transition types to apply to the navigation, passed to `React.addTransitionType` inside the navigation transition.\n```\n\n--------------------------------\n\n ...
#               AIMessage(content='웹 프론트엔드 개발에서 자주 쓰는 패키지/라이브러리를 MCP로 찾아보면, 보통 아래 조합을 많이 사용합니다.\n\n## 기본 필수\n- **React**: UI를 만드는 핵심 라이브러리\n- **React DOM**: 브라우저 렌더링\n- **Next.js**: React 기반 프레임워크. 라우팅, SSR/SSG, 빌드 최적화 포함\n\nMCP로 확인된 Next.js 설치 예시:\n```bash\nnpm i next@latest react@latest react-dom@latest\n```\n\n## 자주 함께 쓰는 라이브러리\n- **라우팅**: Next.js의 `Link`\n- **데이터 패칭**: `SWR`  \n  - 캐싱, 재검증, 로딩 상태 처리에 유리\n- **폼 관리**: `React Hook Form`\n- **검증**: `Zod`\n- **상태 관리**: `Zustand`, `Redux Toolkit`, `Jotai`\n- **스타일링**: `Tailwind CSS`, `styled-components`, `Emotion`\n- **아이콘**: `react-icons`, `lucide-react`\n- **테스트**: `Jest`, `Vitest`, `React Testing Library`, `Playwright`\n- **HTTP 요청**: `fetch`, `axios`\n\n## MCP에서 확인된 예시\n- `SWR`는 Next.js 문서에서 클라이언트 사이드 데이터 페칭용으로 소개됨\n- `Zod`는 폼/API 입력 검증 예시로 소개됨\n- `Link`는 Next.js의 라우팅용 컴포넌트로 제공됨\n\n## 추천 조합\n### 1) 가장 무난한 최신 스택\n- Next.js\n- React\n- TypeScript\n- Tailwind CSS\n- React Hook Form\n- Zod\n- SWR 또는 TanStack Query\n- Zustand\n- Vitest + Testing Library\n- Playwright\n\n### 2) 규모가 큰 서비스\n- Next.js\n- TypeScript\n- Tailwind CSS 또는 CSS Modules\n- TanStack Query\n- Redux Toolkit\n- Zod\n- Playwright\n- Storybook\n\n## 한 줄 추천\n처음 시작한다면:\n**Next.js + TypeScript + Tailwind CSS + React Hook Form + Zod + SWR**  \n이 조합이 가장 무난합니다.\n\n원하시면 제가 다음 단계로  \n**“초보자용 / 실무용 / 대규모 서비스용”**으로 나눠서 패키지 목록을 더 구체적으로 정리해드릴게요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 568, 'prompt_tokens': 5032, 'total_tokens': 5600, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 3712, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrSiqTZI79QhleTwyxHQjNido3LJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06517-b666-7b00-a11e-e3d2a98bddd9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5032, 'output_tokens': 568, 'total_tokens': 5600, 'input_token_details': {'audio': 0, 'cache_read': 3712}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ====================================================================================================
# 웹 프론트엔드 개발에서 자주 쓰는 패키지/라이브러리를 MCP로 찾아보면, 보통 아래 조합을 많이 사용합니다.
#
# ## 기본 필수
# - **React**: UI를 만드는 핵심 라이브러리
# - **React DOM**: 브라우저 렌더링
# - **Next.js**: React 기반 프레임워크. 라우팅, SSR/SSG, 빌드 최적화 포함
#
# MCP로 확인된 Next.js 설치 예시:
# ```bash
# npm i next@latest react@latest react-dom@latest
# ```
#
# ## 자주 함께 쓰는 라이브러리
# - **라우팅**: Next.js의 `Link`
# - **데이터 패칭**: `SWR`
#   - 캐싱, 재검증, 로딩 상태 처리에 유리
# - **폼 관리**: `React Hook Form`
# - **검증**: `Zod`
# - **상태 관리**: `Zustand`, `Redux Toolkit`, `Jotai`
# - **스타일링**: `Tailwind CSS`, `styled-components`, `Emotion`
# - **아이콘**: `react-icons`, `lucide-react`
# - **테스트**: `Jest`, `Vitest`, `React Testing Library`, `Playwright`
# - **HTTP 요청**: `fetch`, `axios`
#
# ## MCP에서 확인된 예시
# - `SWR`는 Next.js 문서에서 클라이언트 사이드 데이터 페칭용으로 소개됨
# - `Zod`는 폼/API 입력 검증 예시로 소개됨
# - `Link`는 Next.js의 라우팅용 컴포넌트로 제공됨
#
# ## 추천 조합
# ### 1) 가장 무난한 최신 스택
# - Next.js
# - React
# - TypeScript
# - Tailwind CSS
# - React Hook Form
# - Zod
# - SWR 또는 TanStack Query
# - Zustand
# - Vitest + Testing Library
# - Playwright
#
# ### 2) 규모가 큰 서비스
# - Next.js
# - TypeScript
# - Tailwind CSS 또는 CSS Modules
# - TanStack Query
# - Redux Toolkit
# - Zod
# - Playwright
# - Storybook
#
# ## 한 줄 추천
# 처음 시작한다면:
# **Next.js + TypeScript + Tailwind CSS + React Hook Form + Zod + SWR**
# 이 조합이 가장 무난합니다.
#
# 원하시면 제가 다음 단계로
# **“초보자용 / 실무용 / 대규모 서비스용”**으로 나눠서 패키지 목록을 더 구체적으로 정리해드릴게요.

# %%
from pprint import pprint

user_query = '여름 - 가을로 가는 중간지점에 먹을만한 음식은?'

state = {'messages': [('human', user_query)]}

response = graph.invoke(state)  # 그래프 실행 (START -> CHATBOT -> (tool 루프) or END)
pprint(response)
print("="*100)
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='여름 - 가을로 가는 중간지점에 먹을만한 음식은?', additional_kwargs={}, response_metadata={}, id='c5f31f60-26e0-4f27-af82-ec2e185419c0'),
#               AIMessage(content='여름에서 가을로 넘어가는 **환절기**에는 너무 차갑거나 너무 무거운 음식보다, **수분 보충 + 속을 편하게 해주는 음식**이 잘 맞아요.\n\n추천해볼 만한 음식은:\n\n- **국물 있는 음식**: 미역국, 북엇국, 된장국, 닭곰탕  \n- **제철 채소/과일**: 배, 사과, 포도, 옥수수, 가지, 오이  \n- **가볍지만 든든한 메뉴**: 비빔밥, 죽, 샐러드에 단백질 추가한 것  \n- **환절기 보양식 느낌**: 삼계탕, 장어구이, 버섯전골  \n- **간식/디저트**: 삶은 옥수수, 고구마, 감자, 따뜻한 차\n\n조금 더 실용적으로 말하면:\n- **더위가 남아 있으면**: 냉국, 샐러드, 과일\n- **아침저녁이 선선해지면**: 국, 찌개, 전골\n- **몸이 피곤하면**: 단백질 있는 따뜻한 음식\n\n원하시면 제가  \n1) **한식 위주**,  \n2) **편의점/배달용**,  \n3) **다이어트용**,  \n4) **저렴한 메뉴**  \n중 하나로 더 구체적으로 추천해드릴게요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 329, 'prompt_tokens': 3179, 'total_tokens': 3508, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EJrUNgar4ZZK04sg02pGR8dIBftfX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06519-4856-7843-979d-7d303fb1a28d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3179, 'output_tokens': 329, 'total_tokens': 3508, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ====================================================================================================
# 여름에서 가을로 넘어가는 **환절기**에는 너무 차갑거나 너무 무거운 음식보다, **수분 보충 + 속을 편하게 해주는 음식**이 잘 맞아요.
#
# 추천해볼 만한 음식은:
#
# - **국물 있는 음식**: 미역국, 북엇국, 된장국, 닭곰탕
# - **제철 채소/과일**: 배, 사과, 포도, 옥수수, 가지, 오이
# - **가볍지만 든든한 메뉴**: 비빔밥, 죽, 샐러드에 단백질 추가한 것
# - **환절기 보양식 느낌**: 삼계탕, 장어구이, 버섯전골
# - **간식/디저트**: 삶은 옥수수, 고구마, 감자, 따뜻한 차
#
# 조금 더 실용적으로 말하면:
# - **더위가 남아 있으면**: 냉국, 샐러드, 과일
# - **아침저녁이 선선해지면**: 국, 찌개, 전골
# - **몸이 피곤하면**: 단백질 있는 따뜻한 음식
#
# 원하시면 제가
# 1) **한식 위주**,
# 2) **편의점/배달용**,
# 3) **다이어트용**,
# 4) **저렴한 메뉴**
# 중 하나로 더 구체적으로 추천해드릴게요.
